# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %% [markdown]
# Abhi colab script me hai ye

# %%
import os
import math
import time
import torch
import torch.nn as nn
from torch.nn import functional as F
from dataclasses import dataclass
from typing import Optional
from tokenizers import Tokenizer, models, trainers, pre_tokenizers
from tokenizers.processors import TemplateProcessing

# ---------------------
# Reproducibility
# ---------------------
torch.manual_seed(1337)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# ---------------------
# Config
# ---------------------
@dataclass
class Config:
    # data
    dataset_path: str = "dataset/new_input.txt"
    tokenizer_dir: str = "tokenizer"
    tokenizer_file: str = "tokenizer/bpe_tokenizer.json"
    vocab_size: int = 8000 # changed from 10000
    force_retrain_tokenizer: bool = False  # set True to retrain with ByteLevel BPE
    # model
    n_embd: int = 384
    n_head: int = 6
    n_layer: int = 4 # changed from 6
    dropout: float = 0.4           # stronger regularization
    emb_dropout: float = 0.1       # new: embedding dropout
    block_size: int = 256
    # training
    batch_size: int = 32 # changed from 64
    max_iters: int = 25000
    eval_interval: int = 1000 # changed from 250
    eval_iters: int = 50 # changed from 200
    learning_rate: float = 3e-4
    min_lr: float = 3e-5
    warmup_iters: int = 2000
    weight_decay: float = 0.1
    betas: tuple = (0.9, 0.95)
    grad_clip: float = 1.0
    grad_accum_steps: int = 2 # changed from 1
    use_amp: bool = True
    patience_evals: int = 6        # new: early stopping patience
    save_every: int = 500
    ckpt_dir: str = "checkpoints"
    resume_path: Optional[str] = None
    # loss
    label_smoothing: float = 0.1   # new: improves generalization
    # generation
    gen_max_new_tokens: int = 700
    gen_temperature: float = 1.0
    gen_top_k: int = 50

cfg = Config()
# === [NEW] Set up Drive output directories ===
import datetime
run_id = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
drive_root = f"/content/drive/MyDrive/gpt_from_scratch_runs/run_{run_id}"

cfg.ckpt_dir = os.path.join(drive_root, "checkpoints")
cfg.tokenizer_dir = os.path.join(drive_root, "tokenizer")
cfg.tokenizer_file = os.path.join(cfg.tokenizer_dir, "bpe_tokenizer.json")
os.makedirs(cfg.ckpt_dir, exist_ok=True)
os.makedirs(cfg.tokenizer_dir, exist_ok=True)

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# ---------------------
# Clone dataset repo (COLAB)
# ---------------------
if not os.path.exists(cfg.dataset_path):
    print("📥 Cloning dataset repo...")
    os.system("git clone https://github.com/DevashishXO/GPT-From-Scratch.git")
    os.chdir("GPT-From-Scratch")
else:
    print("✅ Dataset already exists.")

# ---------------------
# Tokenizer setup
# ---------------------
os.makedirs(cfg.tokenizer_dir, exist_ok=True)

def train_or_load_tokenizer():
    tok_path = cfg.tokenizer_file
    if cfg.force_retrain_tokenizer and os.path.exists(tok_path):
        print("♻️ Forcing tokenizer retrain, removing old file...")
        try:
            os.remove(tok_path)
        except FileNotFoundError:
            pass

    if not os.path.exists(tok_path):
        print("🔧 Training new BPE tokenizer...")
        tokenizer = Tokenizer(models.BPE(unk_token="[UNK]"))
        # ByteLevel is more robust for multilingual/raw punctuation; switch if retraining
        tokenizer.pre_tokenizer = pre_tokenizers.ByteLevel() if cfg.force_retrain_tokenizer else pre_tokenizers.Whitespace()
        trainer = trainers.BpeTrainer(
            vocab_size=cfg.vocab_size,
            special_tokens=["[PAD]", "[UNK]", "[BOS]", "[EOS]"]
        )
        tokenizer.train([cfg.dataset_path], trainer)
        if isinstance(tokenizer.model, models.BPE):
            tokenizer.model.unk_token = "[UNK]"
        bos_id = tokenizer.token_to_id("[BOS]")
        eos_id = tokenizer.token_to_id("[EOS]")
        tokenizer.post_processor = TemplateProcessing(
            single="[BOS] $A [EOS]",
            pair="[BOS] $A [EOS] [BOS] $B [EOS]",
            special_tokens=[("[BOS]", bos_id), ("[EOS]", eos_id)]
        )
        tokenizer.save(tok_path)
        print("✅ Tokenizer trained and saved.")
    else:
        print("✅ Existing tokenizer found. Loading...")
    tokenizer = Tokenizer.from_file(tok_path)
    if isinstance(tokenizer.model, models.BPE) and tokenizer.model.unk_token is None:
        tokenizer.model.unk_token = "[UNK]"
    bos_id = tokenizer.token_to_id("[BOS]")
    eos_id = tokenizer.token_to_id("[EOS]")
    if tokenizer.post_processor is None:
        tokenizer.post_processor = TemplateProcessing(
            single="[BOS] $A [EOS]",
            pair="[BOS] $A [EOS] [BOS] $B [EOS]",
            special_tokens=[("[BOS]", bos_id), ("[EOS]", eos_id)]
        )
    return tokenizer

tokenizer = train_or_load_tokenizer()
vocab_size = tokenizer.get_vocab_size()
print(f"📊 Vocab size: {vocab_size}")

BOS_ID = tokenizer.token_to_id("[BOS]")
EOS_ID = tokenizer.token_to_id("[EOS]")

def encode_text_stream_with_boundaries(txt: str) -> list[int]:
    ids: list[int] = []
    for line in txt.splitlines():
        line = line.strip()
        if not line:
            continue
        ids.extend(tokenizer.encode(line).ids)  # post-processor injects BOS/EOS
    return ids

def decode_ids(ids: list[int]) -> str:
    return tokenizer.decode(ids, skip_special_tokens=True)

# ---------------------
# Load dataset
# ---------------------
with open(cfg.dataset_path, "r", encoding="utf-8") as f:
    raw_text = f.read()
print(f"📖 Dataset length (chars): {len(raw_text):,}")

all_ids = encode_text_stream_with_boundaries(raw_text)
data = torch.tensor(all_ids, dtype=torch.long)
if len(data) < cfg.block_size + 1:
    raise ValueError(f"Encoded dataset too small ({len(data)}) for block_size={cfg.block_size}")

n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

def get_batch(split: str):
    src = train_data if split == 'train' else val_data
    ix = torch.randint(0, len(src) - cfg.block_size, (cfg.batch_size,))
    x = torch.stack([src[i:i+cfg.block_size] for i in ix])
    y = torch.stack([src[i+1:i+cfg.block_size+1] for i in ix])
    return x.to(device), y.to(device)

# ---------------------
# LR schedule
# ---------------------
def cosine_lr(step: int, base_lr: float, min_lr: float, warmup: int, total: int):
    if step < warmup:
        return base_lr * step / max(1, warmup)
    progress = (step - warmup) / max(1, total - warmup)
    return min_lr + 0.5 * (base_lr - min_lr) * (1 + math.cos(math.pi * progress))

# ---------------------
# Model
# ---------------------
class Head(nn.Module):
    def __init__(self, head_size: int):
        super().__init__()
        self.key = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.query = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.value = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(cfg.block_size, cfg.block_size)))
        self.dropout = nn.Dropout(cfg.dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x); q = self.query(x)
        wei = q @ k.transpose(-2, -1) * (k.shape[-1] ** -0.5)
        # AMP-stable mask
        wei = wei.masked_fill(self.tril[:T, :T] == 0, torch.finfo(wei.dtype).min)
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        out = wei @ v
        return out

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads: int, head_size: int):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(head_size * num_heads, cfg.n_embd)
        self.dropout = nn.Dropout(cfg.dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedForward(nn.Module):
    def __init__(self, n_embd: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.GELU(),  # GELU generally improves GPTs
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(cfg.dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    def __init__(self, n_embd: int, n_head: int):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ff = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ff(self.ln2(x))
        return x

class GPTLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, cfg.n_embd)
        self.position_embedding_table = nn.Embedding(cfg.block_size, cfg.n_embd)
        self.drop_emb = nn.Dropout(cfg.emb_dropout)  # new: embedding dropout
        self.blocks = nn.Sequential(*[Block(cfg.n_embd, cfg.n_head) for _ in range(cfg.n_layer)])
        self.ln_f = nn.LayerNorm(cfg.n_embd)
        self.lm_head = nn.Linear(cfg.n_embd, vocab_size, bias=False)
        self.apply(self._init_weights)
        self.tie_weights()

    def tie_weights(self):
        self.lm_head.weight = self.token_embedding_table.weight

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=idx.device))
        x = self.drop_emb(tok_emb + pos_emb)  # apply embedding dropout
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)
        loss = None
        if targets is not None:
            loss = F.cross_entropy(
                logits.view(B*T, -1),
                targets.view(B*T),
                label_smoothing=cfg.label_smoothing,  # new: label smoothing
            )
        return logits, loss

    @torch.no_grad()
    def _sample_next(self, logits_last, temperature=1.0, top_k=50):
        if temperature != 1.0:
            logits_last = logits_last / temperature
        probs = F.softmax(logits_last, dim=-1)
        if top_k is not None and top_k > 0:
            v, ix = torch.topk(probs, top_k)
            mask = torch.ones_like(probs, dtype=torch.bool)
            mask.scatter_(1, ix, False)
            probs = probs.masked_fill(mask, 0)
            probs = probs / probs.sum(dim=-1, keepdim=True)
        next_token = torch.multinomial(probs, num_samples=1)
        return next_token

    @torch.no_grad()
    def generate(self, idx, max_new_tokens, temperature=1.0, top_k=50, eos_id: int | None = None):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -cfg.block_size:]
            logits, _ = self(idx_cond)
            next_token = self._sample_next(logits[:, -1, :], temperature, top_k)
            idx = torch.cat((idx, next_token), dim=1)
            if eos_id is not None and (next_token == eos_id).all():
                break
        return idx

# ---------------------
# Init model/opt/amp
# ---------------------
model = GPTLanguageModel().to(device)

# AdamW param groups: no weight decay on LayerNorm or bias
decay = []
no_decay = []
for name, param in model.named_parameters():
    if name.endswith('bias') or 'ln' in name or 'norm' in name:
        no_decay.append(param)
    else:
        decay.append(param)

optim_groups = [
    {"params": decay, "weight_decay": cfg.weight_decay},
    {"params": no_decay, "weight_decay": 0.0},
]

optimizer = torch.optim.AdamW(
    optim_groups,
    lr=cfg.learning_rate,
    betas=cfg.betas
)

# Use new torch.amp API (fixes deprecation warnings)
scaler = torch.amp.GradScaler('cuda', enabled=(cfg.use_amp and device == 'cuda'))

param_millions = sum(p.numel() for p in model.parameters())/1e6
print(f"🤖 Model parameters: {param_millions:.2f} M")

os.makedirs(cfg.ckpt_dir, exist_ok=True)

start_iter = 0
best_val_loss = float('inf')
no_improve_evals = 0
if cfg.resume_path is not None and os.path.exists(cfg.resume_path):
    ckpt = torch.load(cfg.resume_path, map_location=device)
    model.load_state_dict(ckpt['model'])
    optimizer.load_state_dict(ckpt['opt'])
    start_iter = ckpt.get('iter', 0) + 1
    best_val_loss = ckpt.get('val_loss', float('inf'))
    print(f"🔄 Resumed from {cfg.resume_path} at iter {start_iter}, best_val_loss={best_val_loss:.4f}")

@torch.no_grad()
def estimate_metrics():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(cfg.eval_iters, device=device)
        for k in range(cfg.eval_iters):
            X, Y = get_batch(split)
            with torch.amp.autocast('cuda', enabled=(cfg.use_amp and device == 'cuda')):
                _, loss = model(X, Y)
            losses[k] = loss
        mean_loss = losses.mean().item()
        out[split] = {'loss': mean_loss, 'ppl': math.exp(mean_loss)}
    model.train()
    return out

# ---------------------
# Training
# ---------------------
t0 = time.time()
for iter in range(start_iter, cfg.max_iters):
    lr = cosine_lr(iter, cfg.learning_rate, cfg.min_lr, cfg.warmup_iters, cfg.max_iters)
    for g in optimizer.param_groups:
        g['lr'] = lr

    if iter % 100 == 0 and iter > 0:
        elapsed = time.time() - t0
        print(f"[Progress: {iter}/{cfg.max_iters} ({100*iter/cfg.max_iters:.1f}%)] elapsed {elapsed/60:.1f} min")

    if iter % cfg.eval_interval == 0 or iter == cfg.max_iters - 1:
        metrics = estimate_metrics()
        print(f"Step {iter}: train loss {metrics['train']['loss']:.4f} (ppl {metrics['train']['ppl']:.2f}), "
              f"val loss {metrics['val']['loss']:.4f} (ppl {metrics['val']['ppl']:.2f}), lr {lr:.2e}")
        if metrics['val']['loss'] + 1e-6 < best_val_loss:
            best_val_loss = metrics['val']['loss']
            no_improve_evals = 0
            best_path = os.path.join(cfg.ckpt_dir, "best.pt")
            torch.save({'iter': iter, 'model': model.state_dict(), 'opt': optimizer.state_dict(),
                        'val_loss': best_val_loss, 'cfg': cfg.__dict__}, best_path)
            print(f" -> 💾 Best checkpoint updated: {best_path}")
        else:
            no_improve_evals += 1
            if no_improve_evals >= cfg.patience_evals:
                print(f"⏹️ Early stopping after {no_improve_evals} evals without val improvement.")
                break

    optimizer.zero_grad(set_to_none=True)
    for micro in range(cfg.grad_accum_steps):
        xb, yb = get_batch('train')
        with torch.amp.autocast('cuda', enabled=(cfg.use_amp and device == 'cuda')):
            _, loss = model(xb, yb)
            loss = loss / cfg.grad_accum_steps
        scaler.scale(loss).backward()

    if cfg.grad_clip and cfg.grad_clip > 0:
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)

    scaler.step(optimizer)
    scaler.update()

    if iter > 0 and iter % cfg.save_every == 0:
        ckpt_path = os.path.join(cfg.ckpt_dir, f"checkpoint_{iter}.pt")
        torch.save({'iter': iter, 'model': model.state_dict(), 'opt': optimizer.state_dict(),
                    'val_loss': best_val_loss, 'cfg': cfg.__dict__}, ckpt_path)
        print(f"💾 Checkpoint saved at step {iter}: {ckpt_path}")

# ---------------------
# Save final, generate sample
# ---------------------
final_model_path = os.path.join(cfg.ckpt_dir, "gpt_final.pt")
torch.save(model.state_dict(), final_model_path)
print(f"✅ Final model saved to {final_model_path}")

context = torch.tensor([[BOS_ID]], dtype=torch.long, device=device)
generated_ids = model.generate(
    context,
    max_new_tokens=cfg.gen_max_new_tokens,
    temperature=cfg.gen_temperature,
    top_k=cfg.gen_top_k,
    eos_id=EOS_ID
)[0].tolist()
print("📝 Sample:\n", decode_ids(generated_ids))

# ---------------------
# Zip checkpoints for download (COLAB)
# ---------------------
print("\n📦 Zipping checkpoints for download...")
os.system(f"zip -r checkpoints.zip {cfg.ckpt_dir}")
print("✅ Run this in a new cell to download:")
print("   from google.colab import files")
print("   files.download('checkpoints.zip')")
# Out:
# ✅ Dataset already exists.
# 🔧 Training new BPE tokenizer...
# ✅ Tokenizer trained and saved.
# 📊 Vocab size: 8000
# 📖 Dataset length (chars): 6,793,953
# 🤖 Model parameters: 10.26 M
# Step 0: train loss 9.0770 (ppl 8751.40), val loss 9.0733 (ppl 8719.22), lr 0.00e+00
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/best.pt
# [Progress: 100/25000 (0.4%)] elapsed 0.4 min
# [Progress: 200/25000 (0.8%)] elapsed 0.7 min
# [Progress: 300/25000 (1.2%)] elapsed 1.0 min
# [Progress: 400/25000 (1.6%)] elapsed 1.3 min
# [Progress: 500/25000 (2.0%)] elapsed 1.7 min
# 💾 Checkpoint saved at step 500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_500.pt
# [Progress: 600/25000 (2.4%)] elapsed 2.0 min
# [Progress: 700/25000 (2.8%)] elapsed 2.3 min
# [Progress: 800/25000 (3.2%)] elapsed 2.7 min
# [Progress: 900/25000 (3.6%)] elapsed 3.0 min
# [Progress: 1000/25000 (4.0%)] elapsed 3.3 min
# Step 1000: train loss 5.8889 (ppl 361.01), val loss 6.1432 (ppl 465.52), lr 1.50e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/best.pt
# 💾 Checkpoint saved at step 1000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_1000.pt
# [Progress: 1100/25000 (4.4%)] elapsed 3.7 min
# [Progress: 1200/25000 (4.8%)] elapsed 4.1 min
# [Progress: 1300/25000 (5.2%)] elapsed 4.4 min
# [Progress: 1400/25000 (5.6%)] elapsed 4.7 min
# [Progress: 1500/25000 (6.0%)] elapsed 5.0 min
# 💾 Checkpoint saved at step 1500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_1500.pt
# [Progress: 1600/25000 (6.4%)] elapsed 5.4 min
# [Progress: 1700/25000 (6.8%)] elapsed 5.7 min
# [Progress: 1800/25000 (7.2%)] elapsed 6.0 min
# [Progress: 1900/25000 (7.6%)] elapsed 6.4 min
# [Progress: 2000/25000 (8.0%)] elapsed 6.7 min
# Step 2000: train loss 5.2928 (ppl 198.89), val loss 5.7911 (ppl 327.37), lr 3.00e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/best.pt
# 💾 Checkpoint saved at step 2000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_2000.pt
# [Progress: 2100/25000 (8.4%)] elapsed 7.1 min
# [Progress: 2200/25000 (8.8%)] elapsed 7.4 min
# [Progress: 2300/25000 (9.2%)] elapsed 7.7 min
# [Progress: 2400/25000 (9.6%)] elapsed 8.1 min
# [Progress: 2500/25000 (10.0%)] elapsed 8.4 min
# 💾 Checkpoint saved at step 2500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_2500.pt
# [Progress: 2600/25000 (10.4%)] elapsed 8.7 min
# [Progress: 2700/25000 (10.8%)] elapsed 9.1 min
# [Progress: 2800/25000 (11.2%)] elapsed 9.4 min
# [Progress: 2900/25000 (11.6%)] elapsed 9.7 min
# [Progress: 3000/25000 (12.0%)] elapsed 10.0 min
# Step 3000: train loss 4.9508 (ppl 141.29), val loss 5.6268 (ppl 277.76), lr 2.99e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/best.pt
# 💾 Checkpoint saved at step 3000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_3000.pt
# [Progress: 3100/25000 (12.4%)] elapsed 10.4 min
# [Progress: 3200/25000 (12.8%)] elapsed 10.8 min
# [Progress: 3300/25000 (13.2%)] elapsed 11.1 min
# [Progress: 3400/25000 (13.6%)] elapsed 11.4 min
# [Progress: 3500/25000 (14.0%)] elapsed 11.8 min
# 💾 Checkpoint saved at step 3500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_3500.pt
# [Progress: 3600/25000 (14.4%)] elapsed 12.1 min
# [Progress: 3700/25000 (14.8%)] elapsed 12.4 min
# [Progress: 3800/25000 (15.2%)] elapsed 12.7 min
# [Progress: 3900/25000 (15.6%)] elapsed 13.1 min
# [Progress: 4000/25000 (16.0%)] elapsed 13.4 min
# Step 4000: train loss 4.7515 (ppl 115.75), val loss 5.5647 (ppl 261.05), lr 2.95e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/best.pt
# 💾 Checkpoint saved at step 4000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_4000.pt
# [Progress: 4100/25000 (16.4%)] elapsed 13.8 min
# [Progress: 4200/25000 (16.8%)] elapsed 14.1 min
# [Progress: 4300/25000 (17.2%)] elapsed 14.5 min
# [Progress: 4400/25000 (17.6%)] elapsed 14.8 min
# [Progress: 4500/25000 (18.0%)] elapsed 15.1 min
# 💾 Checkpoint saved at step 4500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_4500.pt
# [Progress: 4600/25000 (18.4%)] elapsed 15.4 min
# [Progress: 4700/25000 (18.8%)] elapsed 15.8 min
# [Progress: 4800/25000 (19.2%)] elapsed 16.1 min
# [Progress: 4900/25000 (19.6%)] elapsed 16.4 min
# [Progress: 5000/25000 (20.0%)] elapsed 16.7 min
# Step 5000: train loss 4.6062 (ppl 100.10), val loss 5.5248 (ppl 250.85), lr 2.89e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/best.pt
# 💾 Checkpoint saved at step 5000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_5000.pt
# [Progress: 5100/25000 (20.4%)] elapsed 17.1 min
# [Progress: 5200/25000 (20.8%)] elapsed 17.5 min
# [Progress: 5300/25000 (21.2%)] elapsed 17.8 min
# [Progress: 5400/25000 (21.6%)] elapsed 18.1 min
# [Progress: 5500/25000 (22.0%)] elapsed 18.5 min
# 💾 Checkpoint saved at step 5500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_5500.pt
# [Progress: 5600/25000 (22.4%)] elapsed 18.8 min
# [Progress: 5700/25000 (22.8%)] elapsed 19.1 min
# [Progress: 5800/25000 (23.2%)] elapsed 19.4 min
# [Progress: 5900/25000 (23.6%)] elapsed 19.8 min
# [Progress: 6000/25000 (24.0%)] elapsed 20.1 min
# Step 6000: train loss 4.4824 (ppl 88.44), val loss 5.5111 (ppl 247.42), lr 2.80e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/best.pt
# 💾 Checkpoint saved at step 6000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_6000.pt
# [Progress: 6100/25000 (24.4%)] elapsed 20.5 min
# [Progress: 6200/25000 (24.8%)] elapsed 20.8 min
# [Progress: 6300/25000 (25.2%)] elapsed 21.2 min
# [Progress: 6400/25000 (25.6%)] elapsed 21.5 min
# [Progress: 6500/25000 (26.0%)] elapsed 21.8 min
# 💾 Checkpoint saved at step 6500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_6500.pt
# [Progress: 6600/25000 (26.4%)] elapsed 22.2 min
# [Progress: 6700/25000 (26.8%)] elapsed 22.5 min
# [Progress: 6800/25000 (27.2%)] elapsed 22.8 min
# [Progress: 6900/25000 (27.6%)] elapsed 23.1 min
# [Progress: 7000/25000 (28.0%)] elapsed 23.5 min
# Step 7000: train loss 4.3840 (ppl 80.16), val loss 5.4884 (ppl 241.88), lr 2.70e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/best.pt
# 💾 Checkpoint saved at step 7000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_7000.pt
# [Progress: 7100/25000 (28.4%)] elapsed 23.9 min
# [Progress: 7200/25000 (28.8%)] elapsed 24.2 min
# [Progress: 7300/25000 (29.2%)] elapsed 24.5 min
# [Progress: 7400/25000 (29.6%)] elapsed 24.9 min
# [Progress: 7500/25000 (30.0%)] elapsed 25.2 min
# 💾 Checkpoint saved at step 7500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_7500.pt
# [Progress: 7600/25000 (30.4%)] elapsed 25.5 min
# [Progress: 7700/25000 (30.8%)] elapsed 25.8 min
# [Progress: 7800/25000 (31.2%)] elapsed 26.2 min
# [Progress: 7900/25000 (31.6%)] elapsed 26.5 min
# [Progress: 8000/25000 (32.0%)] elapsed 26.8 min
# Step 8000: train loss 4.2876 (ppl 72.79), val loss 5.4587 (ppl 234.80), lr 2.57e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/best.pt
# 💾 Checkpoint saved at step 8000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_8000.pt
# [Progress: 8100/25000 (32.4%)] elapsed 27.2 min
# [Progress: 8200/25000 (32.8%)] elapsed 27.6 min
# [Progress: 8300/25000 (33.2%)] elapsed 27.9 min
# [Progress: 8400/25000 (33.6%)] elapsed 28.2 min
# [Progress: 8500/25000 (34.0%)] elapsed 28.5 min
# 💾 Checkpoint saved at step 8500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_8500.pt
# [Progress: 8600/25000 (34.4%)] elapsed 28.9 min
# [Progress: 8700/25000 (34.8%)] elapsed 29.2 min
# [Progress: 8800/25000 (35.2%)] elapsed 29.5 min
# [Progress: 8900/25000 (35.6%)] elapsed 29.9 min
# [Progress: 9000/25000 (36.0%)] elapsed 30.2 min
# Step 9000: train loss 4.2220 (ppl 68.17), val loss 5.4846 (ppl 240.95), lr 2.43e-04
# 💾 Checkpoint saved at step 9000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_9000.pt
# [Progress: 9100/25000 (36.4%)] elapsed 30.6 min
# [Progress: 9200/25000 (36.8%)] elapsed 30.9 min
# [Progress: 9300/25000 (37.2%)] elapsed 31.2 min
# [Progress: 9400/25000 (37.6%)] elapsed 31.6 min
# [Progress: 9500/25000 (38.0%)] elapsed 31.9 min
# 💾 Checkpoint saved at step 9500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_9500.pt
# [Progress: 9600/25000 (38.4%)] elapsed 32.2 min
# [Progress: 9700/25000 (38.8%)] elapsed 32.6 min
# [Progress: 9800/25000 (39.2%)] elapsed 32.9 min
# [Progress: 9900/25000 (39.6%)] elapsed 33.2 min
# [Progress: 10000/25000 (40.0%)] elapsed 33.6 min
# Step 10000: train loss 4.1706 (ppl 64.75), val loss 5.4762 (ppl 238.93), lr 2.27e-04
# 💾 Checkpoint saved at step 10000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_10000.pt
# [Progress: 10100/25000 (40.4%)] elapsed 33.9 min
# [Progress: 10200/25000 (40.8%)] elapsed 34.3 min
# [Progress: 10300/25000 (41.2%)] elapsed 34.6 min
# [Progress: 10400/25000 (41.6%)] elapsed 34.9 min
# [Progress: 10500/25000 (42.0%)] elapsed 35.3 min
# 💾 Checkpoint saved at step 10500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_10500.pt
# [Progress: 10600/25000 (42.4%)] elapsed 35.6 min
# [Progress: 10700/25000 (42.8%)] elapsed 35.9 min
# [Progress: 10800/25000 (43.2%)] elapsed 36.3 min
# [Progress: 10900/25000 (43.6%)] elapsed 36.6 min
# [Progress: 11000/25000 (44.0%)] elapsed 36.9 min
# Step 11000: train loss 4.1078 (ppl 60.82), val loss 5.4842 (ppl 240.86), lr 2.10e-04
# 💾 Checkpoint saved at step 11000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_11000.pt
# [Progress: 11100/25000 (44.4%)] elapsed 37.3 min
# [Progress: 11200/25000 (44.8%)] elapsed 37.6 min
# [Progress: 11300/25000 (45.2%)] elapsed 38.0 min
# [Progress: 11400/25000 (45.6%)] elapsed 38.3 min
# [Progress: 11500/25000 (46.0%)] elapsed 38.6 min
# 💾 Checkpoint saved at step 11500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_11500.pt
# [Progress: 11600/25000 (46.4%)] elapsed 39.0 min
# [Progress: 11700/25000 (46.8%)] elapsed 39.3 min
# [Progress: 11800/25000 (47.2%)] elapsed 39.6 min
# [Progress: 11900/25000 (47.6%)] elapsed 39.9 min
# [Progress: 12000/25000 (48.0%)] elapsed 40.3 min
# Step 12000: train loss 4.0592 (ppl 57.93), val loss 5.4737 (ppl 238.34), lr 1.92e-04
# 💾 Checkpoint saved at step 12000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_12000.pt
# [Progress: 12100/25000 (48.4%)] elapsed 40.7 min
# [Progress: 12200/25000 (48.8%)] elapsed 41.0 min
# [Progress: 12300/25000 (49.2%)] elapsed 41.3 min
# [Progress: 12400/25000 (49.6%)] elapsed 41.6 min
# [Progress: 12500/25000 (50.0%)] elapsed 42.0 min
# 💾 Checkpoint saved at step 12500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_12500.pt
# [Progress: 12600/25000 (50.4%)] elapsed 42.3 min
# [Progress: 12700/25000 (50.8%)] elapsed 42.6 min
# [Progress: 12800/25000 (51.2%)] elapsed 43.0 min
# [Progress: 12900/25000 (51.6%)] elapsed 43.3 min
# [Progress: 13000/25000 (52.0%)] elapsed 43.6 min
# Step 13000: train loss 4.0340 (ppl 56.49), val loss 5.5044 (ppl 245.78), lr 1.74e-04
# 💾 Checkpoint saved at step 13000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_13000.pt
# [Progress: 13100/25000 (52.4%)] elapsed 44.0 min
# [Progress: 13200/25000 (52.8%)] elapsed 44.3 min
# [Progress: 13300/25000 (53.2%)] elapsed 44.7 min
# [Progress: 13400/25000 (53.6%)] elapsed 45.0 min
# [Progress: 13500/25000 (54.0%)] elapsed 45.3 min
# 💾 Checkpoint saved at step 13500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/checkpoint_13500.pt
# [Progress: 13600/25000 (54.4%)] elapsed 45.6 min
# [Progress: 13700/25000 (54.8%)] elapsed 46.0 min
# [Progress: 13800/25000 (55.2%)] elapsed 46.3 min
# [Progress: 13900/25000 (55.6%)] elapsed 46.6 min
# [Progress: 14000/25000 (56.0%)] elapsed 47.0 min
# Step 14000: train loss 3.9842 (ppl 53.74), val loss 5.5063 (ppl 246.24), lr 1.56e-04
# ⏹️ Early stopping after 6 evals without val improvement.
# ✅ Final model saved to /content/drive/MyDrive/gpt_from_scratch_runs/run_20251118_121835/checkpoints/gpt_final.pt
# 📝 Sample:
#  अब एक दिन तक उसने अपनी दुर्बलता का अनुभव किया था और वह केवल अपने प्रेम की रक्षा के सामने सिर झुका , उसका देव तुल पित तलवार और तलवार ें , उसे बे मौका ही न था ।
#
# 📦 Zipping checkpoints for download...
# ✅ Run this in a new cell to download:
#    from google.colab import files
#    files.download('checkpoints.zip')

# %% [markdown]
# # Comparing Attention Mechanisms!

# %% [markdown]
# **1) MultiHead Attention**

# %%
import os
import math
import time
import torch
import torch.nn as nn
from torch.nn import functional as F
from dataclasses import dataclass
from typing import Optional
from tokenizers import Tokenizer, models, trainers, pre_tokenizers
from tokenizers.processors import TemplateProcessing

# ---------------------
# Reproducibility
# ---------------------
torch.manual_seed(1337)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# ---------------------
# Config
# ---------------------
@dataclass
class Config:
    # data
    dataset_path: str = "dataset/new_input.txt"
    tokenizer_dir: str = "tokenizer"
    tokenizer_file: str = "tokenizer/bpe_tokenizer.json"
    vocab_size: int = 8000 # changed from 10000
    force_retrain_tokenizer: bool = False  # set True to retrain with ByteLevel BPE
    dataset_token_limit: Optional[int] = 1_500_000  # NEW: faster runs
    # model
    n_embd: int = 320               # CHANGED: 384 -> 320 (faster)
    n_head: int = 6
    n_layer: int = 3                # CHANGED: 4 -> 3 (faster)
    dropout: float = 0.5            # stronger regularization
    emb_dropout: float = 0.1        # new: embedding dropout
    block_size: int = 256
    # attention selection
    attn_type: str = "mha"        # NEW: "mha" | "mqa" | "gqa" | "mlha"
    num_kv_heads: int = 1         # NEW: for MQA/GQA (MQA=1, GQA>1 and divides n_head)
    latent_kv_heads: int = 2      # NEW: for MLHA (# latent K/V heads)
    # training
    batch_size: int = 32 # changed from 64
    max_iters: int = 5000 # changed from 25000 for faster runs
    eval_interval: int = 500      # CHANGED: 1000 -> 500
    eval_iters: int = 50 # changed from 200
    learning_rate: float = 3e-4
    min_lr: float = 3e-5
    warmup_iters: int = 1000      # CHANGED: 2000 -> 1000
    weight_decay: float = 0.1
    betas: tuple = (0.9, 0.95)
    grad_clip: float = 1.0
    grad_accum_steps: int = 2 # changed from 1
    use_amp: bool = True
    patience_evals: int = 6        # new: early stopping patience
    save_every: int = 500
    ckpt_dir: str = "checkpoints"
    resume_path: Optional[str] = None
    use_best_for_generation: bool = True   # NEW
    # loss
    label_smoothing: float = 0.1   # new: improves generalization
    # generation
    gen_max_new_tokens: int = 700
    gen_temperature: float = 1.0
    gen_top_k: int = 50

cfg = Config()
# === [NEW] Set up Drive output directories ===
import datetime
run_id = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
drive_root = f"/content/drive/MyDrive/gpt_from_scratch_runs/run_{run_id}"

cfg.ckpt_dir = os.path.join(drive_root, "checkpoints")
cfg.tokenizer_dir = os.path.join(drive_root, "tokenizer")
cfg.tokenizer_file = os.path.join(cfg.tokenizer_dir, "bpe_tokenizer.json")
os.makedirs(cfg.ckpt_dir, exist_ok=True)
os.makedirs(cfg.tokenizer_dir, exist_ok=True)

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# ---------------------
# Clone dataset repo (COLAB)
# ---------------------
if not os.path.exists(cfg.dataset_path):
    print("📥 Cloning dataset repo...")
    os.system("git clone https://github.com/DevashishXO/GPT-From-Scratch.git")
    os.chdir("GPT-From-Scratch")
else:
    print("✅ Dataset already exists.")

# ---------------------
# Tokenizer setup
# ---------------------
os.makedirs(cfg.tokenizer_dir, exist_ok=True)

def train_or_load_tokenizer():
    tok_path = cfg.tokenizer_file
    if cfg.force_retrain_tokenizer and os.path.exists(tok_path):
        print("♻️ Forcing tokenizer retrain, removing old file...")
        try:
            os.remove(tok_path)
        except FileNotFoundError:
            pass

    if not os.path.exists(tok_path):
        print("🔧 Training new BPE tokenizer...")
        tokenizer = Tokenizer(models.BPE(unk_token="[UNK]"))
        # ByteLevel is more robust for multilingual/raw punctuation; switch if retraining
        tokenizer.pre_tokenizer = pre_tokenizers.ByteLevel() if cfg.force_retrain_tokenizer else pre_tokenizers.Whitespace()
        trainer = trainers.BpeTrainer(
            vocab_size=cfg.vocab_size,
            special_tokens=["[PAD]", "[UNK]", "[BOS]", "[EOS]"]
        )
        tokenizer.train([cfg.dataset_path], trainer)
        if isinstance(tokenizer.model, models.BPE):
            tokenizer.model.unk_token = "[UNK]"
        bos_id = tokenizer.token_to_id("[BOS]")
        eos_id = tokenizer.token_to_id("[EOS]")
        tokenizer.post_processor = TemplateProcessing(
            single="[BOS] $A [EOS]",
            pair="[BOS] $A [EOS] [BOS] $B [EOS]",
            special_tokens=[("[BOS]", bos_id), ("[EOS]", eos_id)]
        )
        tokenizer.save(tok_path)
        print("✅ Tokenizer trained and saved.")
    else:
        print("✅ Existing tokenizer found. Loading...")
    tokenizer = Tokenizer.from_file(tok_path)
    if isinstance(tokenizer.model, models.BPE) and tokenizer.model.unk_token is None:
        tokenizer.model.unk_token = "[UNK]"
    bos_id = tokenizer.token_to_id("[BOS]")
    eos_id = tokenizer.token_to_id("[EOS]")
    if tokenizer.post_processor is None:
        tokenizer.post_processor = TemplateProcessing(
            single="[BOS] $A [EOS]",
            pair="[BOS] $A [EOS] [BOS] $B [EOS]",
            special_tokens=[("[BOS]", bos_id), ("[EOS]", eos_id)]
        )
    return tokenizer

tokenizer = train_or_load_tokenizer()
vocab_size = tokenizer.get_vocab_size()
print(f"📊 Vocab size: {vocab_size}")

BOS_ID = tokenizer.token_to_id("[BOS]")
EOS_ID = tokenizer.token_to_id("[EOS]")

def encode_text_stream_with_boundaries(txt: str) -> list[int]:
    ids: list[int] = []
    for line in txt.splitlines():
        line = line.strip()
        if not line:
            continue
        ids.extend(tokenizer.encode(line).ids)  # post-processor injects BOS/EOS
    return ids

def decode_ids(ids: list[int]) -> str:
    return tokenizer.decode(ids, skip_special_tokens=True)

# ---------------------
# Load dataset
# ---------------------
with open(cfg.dataset_path, "r", encoding="utf-8") as f:
    raw_text = f.read()
print(f"📖 Dataset length (chars): {len(raw_text):,}")

all_ids = encode_text_stream_with_boundaries(raw_text)
data = torch.tensor(all_ids, dtype=torch.long)
if len(data) < cfg.block_size + 1:
    raise ValueError(f"Encoded dataset too small ({len(data)}) for block_size={cfg.block_size}")

n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

def get_batch(split: str):
    src = train_data if split == 'train' else val_data
    ix = torch.randint(0, len(src) - cfg.block_size, (cfg.batch_size,))
    x = torch.stack([src[i:i+cfg.block_size] for i in ix])
    y = torch.stack([src[i+1:i+cfg.block_size+1] for i in ix])
    return x.to(device), y.to(device)

# ---------------------
# LR schedule
# ---------------------
def cosine_lr(step: int, base_lr: float, min_lr: float, warmup: int, total: int):
    if step < warmup:
        return base_lr * step / max(1, warmup)
    progress = (step - warmup) / max(1, total - warmup)
    return min_lr + 0.5 * (base_lr - min_lr) * (1 + math.cos(math.pi * progress))

# ---------------------
# Model
# ---------------------
class Head(nn.Module):
    def __init__(self, head_size: int):
        super().__init__()
        self.key = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.query = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.value = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(cfg.block_size, cfg.block_size)))
        self.dropout = nn.Dropout(cfg.dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x); q = self.query(x)
        wei = q @ k.transpose(-2, -1) * (k.shape[-1] ** -0.5)
        # AMP-stable mask
        wei = wei.masked_fill(self.tril[:T, :T] == 0, torch.finfo(wei.dtype).min)
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        out = wei @ v
        return out

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads: int, head_size: int):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(head_size * num_heads, cfg.n_embd)
        self.dropout = nn.Dropout(cfg.dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out
    pass

# NEW: MQA/GQA/MLHA implementations (project Q/K/V once and reshape)
class MultiQueryAttention(nn.Module):
    def __init__(self, n_embd: int, n_head: int, kv_heads: int):
        super().__init__()
        assert n_head % kv_heads == 0, "n_head must be divisible by kv_heads"
        self.n_head = n_head
        self.kv_heads = kv_heads
        self.head_size = n_embd // n_head
        self.q_proj = nn.Linear(n_embd, n_head * self.head_size, bias=False)
        self.k_proj = nn.Linear(n_embd, kv_heads * self.head_size, bias=False)
        self.v_proj = nn.Linear(n_embd, kv_heads * self.head_size, bias=False)
        self.proj = nn.Linear(n_head * self.head_size, n_embd)
        self.dropout = nn.Dropout(cfg.dropout)
        self.register_buffer('tril', torch.tril(torch.ones(cfg.block_size, cfg.block_size)))

    def forward(self, x):
        B, T, C = x.shape
        q = self.q_proj(x).view(B, T, self.n_head, self.head_size).transpose(1, 2)  # (B,H,T,dh)
        k = self.k_proj(x).view(B, T, self.kv_heads, self.head_size).transpose(1, 2)  # (B,KV,T,dh)
        v = self.v_proj(x).view(B, T, self.kv_heads, self.head_size).transpose(1, 2)  # (B,KV,T,dh)

        if self.kv_heads != self.n_head:
            repeat = self.n_head // self.kv_heads
            k = k.repeat_interleave(repeat, dim=1)  # (B,H,T,dh)
            v = v.repeat_interleave(repeat, dim=1)  # (B,H,T,dh)

        att = (q @ k.transpose(-2, -1)) * (self.head_size ** -0.5)  # (B,H,T,T)
        att = att.masked_fill(self.tril[:T, :T] == 0, torch.finfo(att.dtype).min)
        att = F.softmax(att, dim=-1)
        att = self.dropout(att)
        out = att @ v  # (B,H,T,dh)
        out = out.transpose(1, 2).contiguous().view(B, T, self.n_head * self.head_size)
        return self.dropout(self.proj(out))

class MultiHeadLatentAttention(nn.Module):
    def __init__(self, n_embd: int, n_head: int, latent_heads: int):
        super().__init__()
        assert n_head >= 1 and latent_heads >= 1
        self.n_head = n_head
        self.latent_heads = latent_heads
        self.head_size = n_embd // n_head
        self.q_proj = nn.Linear(n_embd, n_head * self.head_size, bias=False)
        self.k_lat_proj = nn.Linear(n_embd, latent_heads * self.head_size, bias=False)
        self.v_lat_proj = nn.Linear(n_embd, latent_heads * self.head_size, bias=False)
        # mixing matrix to map latent heads -> per-head K/V
        self.mix = nn.Parameter(torch.empty(n_head, latent_heads))
        nn.init.normal_(self.mix, mean=0.0, std=1.0 / max(1, latent_heads))
        self.proj = nn.Linear(n_head * self.head_size, n_embd)
        self.dropout = nn.Dropout(cfg.dropout)
        self.register_buffer('tril', torch.tril(torch.ones(cfg.block_size, cfg.block_size)))

    def forward(self, x):
        B, T, C = x.shape
        q = self.q_proj(x).view(B, T, self.n_head, self.head_size).transpose(1, 2)  # (B,H,T,dh)
        k_lat = self.k_lat_proj(x).view(B, T, self.latent_heads, self.head_size).transpose(1, 2)  # (B,L,T,dh)
        v_lat = self.v_lat_proj(x).view(B, T, self.latent_heads, self.head_size).transpose(1, 2)  # (B,L,T,dh)

        w = torch.softmax(self.mix, dim=-1)  # (H,L)
        # mix latent K/V into per-head K/V
        k = torch.einsum("bltd,hl->bhtd", k_lat, w)  # (B,H,T,dh)
        v = torch.einsum("bltd,hl->bhtd", v_lat, w)  # (B,H,T,dh)

        att = (q @ k.transpose(-2, -1)) * (self.head_size ** -0.5)  # (B,H,T,T)
        att = att.masked_fill(self.tril[:T, :T] == 0, torch.finfo(att.dtype).min)
        att = F.softmax(att, dim=-1)
        att = self.dropout(att)
        out = att @ v  # (B,H,T,dh)
        out = out.transpose(1, 2).contiguous().view(B, T, self.n_head * self.head_size)
        return self.dropout(self.proj(out))

class FeedForward(nn.Module):
    def __init__(self, n_embd: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.GELU(),  # GELU generally improves GPTs
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(cfg.dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    def __init__(self, n_embd: int, n_head: int):
        super().__init__()
        head_size = n_embd // n_head
# SELECT ATTENTION HERE
        if cfg.attn_type == "mha":
            self.sa = MultiHeadAttention(n_head, head_size)
        elif cfg.attn_type == "mqa":
            self.sa = MultiQueryAttention(n_embd=n_embd, n_head=n_head, kv_heads=1)
        elif cfg.attn_type == "gqa":
            self.sa = MultiQueryAttention(n_embd=n_embd, n_head=n_head, kv_heads=cfg.num_kv_heads)
        elif cfg.attn_type == "mlha":
            self.sa = MultiHeadLatentAttention(n_embd=n_embd, n_head=n_head, latent_heads=cfg.latent_kv_heads)
        else:
            raise ValueError(f"Unknown attn_type: {cfg.attn_type}")
        self.ff = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ff(self.ln2(x))
        return x

class GPTLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, cfg.n_embd)
        self.position_embedding_table = nn.Embedding(cfg.block_size, cfg.n_embd)
        self.drop_emb = nn.Dropout(cfg.emb_dropout)  # new: embedding dropout
        self.blocks = nn.Sequential(*[Block(cfg.n_embd, cfg.n_head) for _ in range(cfg.n_layer)])
        self.ln_f = nn.LayerNorm(cfg.n_embd)
        self.lm_head = nn.Linear(cfg.n_embd, vocab_size, bias=False)
        self.apply(self._init_weights)
        self.tie_weights()

    def tie_weights(self):
        self.lm_head.weight = self.token_embedding_table.weight

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=idx.device))
        x = self.drop_emb(tok_emb + pos_emb)  # apply embedding dropout
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)
        loss = None
        if targets is not None:
            loss = F.cross_entropy(
                logits.view(B*T, -1),
                targets.view(B*T),
                label_smoothing=cfg.label_smoothing,  # new: label smoothing
            )
        return logits, loss

    @torch.no_grad()
    def _sample_next(self, logits_last, temperature=1.0, top_k=50):
        if temperature != 1.0:
            logits_last = logits_last / temperature
        probs = F.softmax(logits_last, dim=-1)
        if top_k is not None and top_k > 0:
            v, ix = torch.topk(probs, top_k)
            mask = torch.ones_like(probs, dtype=torch.bool)
            mask.scatter_(1, ix, False)
            probs = probs.masked_fill(mask, 0)
            probs = probs / probs.sum(dim=-1, keepdim=True)
        next_token = torch.multinomial(probs, num_samples=1)
        return next_token

    @torch.no_grad()
    def generate(self, idx, max_new_tokens, temperature=1.0, top_k=50, eos_id: int | None = None):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -cfg.block_size:]
            logits, _ = self(idx_cond)
            next_token = self._sample_next(logits[:, -1, :], temperature, top_k)
            idx = torch.cat((idx, next_token), dim=1)
            if eos_id is not None and (next_token == eos_id).all():
                break
        return idx

# ---------------------
# Init model/opt/amp
# ---------------------
model = GPTLanguageModel().to(device)

# AdamW param groups: no weight decay on LayerNorm or bias
decay = []
no_decay = []
for name, param in model.named_parameters():
    if name.endswith('bias') or 'ln' in name or 'norm' in name:
        no_decay.append(param)
    else:
        decay.append(param)

optim_groups = [
    {"params": decay, "weight_decay": cfg.weight_decay},
    {"params": no_decay, "weight_decay": 0.0},
]

optimizer = torch.optim.AdamW(
    optim_groups,
    lr=cfg.learning_rate,
    betas=cfg.betas
)

# Use new torch.amp API (fixes deprecation warnings)
scaler = torch.amp.GradScaler('cuda', enabled=(cfg.use_amp and device == 'cuda'))

param_millions = sum(p.numel() for p in model.parameters())/1e6
print(f"🤖 Model parameters: {param_millions:.2f} M")

os.makedirs(cfg.ckpt_dir, exist_ok=True)

start_iter = 0
best_val_loss = float('inf')
no_improve_evals = 0
if cfg.resume_path is not None and os.path.exists(cfg.resume_path):
    ckpt = torch.load(cfg.resume_path, map_location=device)
    model.load_state_dict(ckpt['model'])
    optimizer.load_state_dict(ckpt['opt'])
    start_iter = ckpt.get('iter', 0) + 1
    best_val_loss = ckpt.get('val_loss', float('inf'))
    print(f"🔄 Resumed from {cfg.resume_path} at iter {start_iter}, best_val_loss={best_val_loss:.4f}")

@torch.no_grad()
def estimate_metrics():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(cfg.eval_iters, device=device)
        for k in range(cfg.eval_iters):
            X, Y = get_batch(split)
            with torch.amp.autocast('cuda', enabled=(cfg.use_amp and device == 'cuda')):
                _, loss = model(X, Y)
            losses[k] = loss
        mean_loss = losses.mean().item()
        out[split] = {'loss': mean_loss, 'ppl': math.exp(mean_loss)}
    model.train()
    return out

# ---------------------
# Training
# ---------------------
t0 = time.time()
for iter in range(start_iter, cfg.max_iters):
    lr = cosine_lr(iter, cfg.learning_rate, cfg.min_lr, cfg.warmup_iters, cfg.max_iters)
    for g in optimizer.param_groups:
        g['lr'] = lr

    if iter % 100 == 0 and iter > 0:
        elapsed = time.time() - t0
        print(f"[Progress: {iter}/{cfg.max_iters} ({100*iter/cfg.max_iters:.1f}%)] elapsed {elapsed/60:.1f} min")

    if iter % cfg.eval_interval == 0 or iter == cfg.max_iters - 1:
        metrics = estimate_metrics()
        print(f"Step {iter}: train loss {metrics['train']['loss']:.4f} (ppl {metrics['train']['ppl']:.2f}), "
              f"val loss {metrics['val']['loss']:.4f} (ppl {metrics['val']['ppl']:.2f}), lr {lr:.2e}")
        if metrics['val']['loss'] + 1e-6 < best_val_loss:
            best_val_loss = metrics['val']['loss']
            no_improve_evals = 0
            best_path = os.path.join(cfg.ckpt_dir, "best.pt")
            torch.save({'iter': iter, 'model': model.state_dict(), 'opt': optimizer.state_dict(),
                        'val_loss': best_val_loss, 'cfg': cfg.__dict__}, best_path)
            print(f" -> 💾 Best checkpoint updated: {best_path}")
        else:
            no_improve_evals += 1
            if no_improve_evals >= cfg.patience_evals:
                print(f"⏹️ Early stopping after {no_improve_evals} evals without val improvement.")
                break

    optimizer.zero_grad(set_to_none=True)
    for micro in range(cfg.grad_accum_steps):
        xb, yb = get_batch('train')
        with torch.amp.autocast('cuda', enabled=(cfg.use_amp and device == 'cuda')):
            _, loss = model(xb, yb)
            loss = loss / cfg.grad_accum_steps
        scaler.scale(loss).backward()

    if cfg.grad_clip and cfg.grad_clip > 0:
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)

    scaler.step(optimizer)
    scaler.update()

    if iter > 0 and iter % cfg.save_every == 0:
        ckpt_path = os.path.join(cfg.ckpt_dir, f"checkpoint_{iter}.pt")
        torch.save({'iter': iter, 'model': model.state_dict(), 'opt': optimizer.state_dict(),
                    'val_loss': best_val_loss, 'cfg': cfg.__dict__}, ckpt_path)
        print(f"💾 Checkpoint saved at step {iter}: {ckpt_path}")

# ---------------------
# Save final, generate sample
# ---------------------
final_model_path = os.path.join(cfg.ckpt_dir, "gpt_final.pt")
torch.save(model.state_dict(), final_model_path)
print(f"✅ Final model saved to {final_model_path}")

# NEW: optionally reload best.pt for generation
best_path = os.path.join(cfg.ckpt_dir, "best.pt")
if cfg.use_best_for_generation and os.path.exists(best_path):
    try:
        ckpt = torch.load(best_path, map_location=device)
        model.load_state_dict(ckpt["model"])
        print(f"🌟 Loaded best checkpoint for generation: {best_path}")
    except Exception as e:
        print(f"⚠️ Could not load best.pt for generation: {e}")

context = torch.tensor([[BOS_ID]], dtype=torch.long, device=device)
generated_ids = model.generate(
    context,
    max_new_tokens=cfg.gen_max_new_tokens,
    temperature=cfg.gen_temperature,
    top_k=cfg.gen_top_k,
    eos_id=EOS_ID
)[0].tolist()
print("📝 Sample:\n", decode_ids(generated_ids))

# ---------------------
# Zip checkpoints for download (COLAB)
# ---------------------
print("\n📦 Zipping checkpoints for download...")
os.system(f"zip -r checkpoints.zip {cfg.ckpt_dir}")
print("✅ Run this in a new cell to download:")
print("   from google.colab import files")
print("   files.download('checkpoints.zip')")
# Out:
# 📥 Cloning dataset repo...
# 🔧 Training new BPE tokenizer...
# ✅ Tokenizer trained and saved.
# 📊 Vocab size: 8000
# 📖 Dataset length (chars): 6,793,953
# 🤖 Model parameters: 6.33 M
# Step 0: train loss 9.0347 (ppl 8389.58), val loss 9.0315 (ppl 8362.32), lr 0.00e+00
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/best.pt
# [Progress: 100/5000 (2.0%)] elapsed 0.3 min
# [Progress: 200/5000 (4.0%)] elapsed 0.6 min
# [Progress: 300/5000 (6.0%)] elapsed 0.9 min
# [Progress: 400/5000 (8.0%)] elapsed 1.1 min
# [Progress: 500/5000 (10.0%)] elapsed 1.4 min
# Step 500: train loss 6.2711 (ppl 529.08), val loss 6.4562 (ppl 636.67), lr 1.50e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/best.pt
# 💾 Checkpoint saved at step 500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/checkpoint_500.pt
# [Progress: 600/5000 (12.0%)] elapsed 1.7 min
# [Progress: 700/5000 (14.0%)] elapsed 2.0 min
# [Progress: 800/5000 (16.0%)] elapsed 2.2 min
# [Progress: 900/5000 (18.0%)] elapsed 2.5 min
# [Progress: 1000/5000 (20.0%)] elapsed 2.8 min
# Step 1000: train loss 5.7919 (ppl 327.65), val loss 6.1114 (ppl 450.97), lr 3.00e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/best.pt
# 💾 Checkpoint saved at step 1000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/checkpoint_1000.pt
# [Progress: 1100/5000 (22.0%)] elapsed 3.1 min
# [Progress: 1200/5000 (24.0%)] elapsed 3.4 min
# [Progress: 1300/5000 (26.0%)] elapsed 3.6 min
# [Progress: 1400/5000 (28.0%)] elapsed 3.9 min
# [Progress: 1500/5000 (30.0%)] elapsed 4.2 min
# Step 1500: train loss 5.5163 (ppl 248.72), val loss 5.9461 (ppl 382.25), lr 2.90e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/best.pt
# 💾 Checkpoint saved at step 1500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/checkpoint_1500.pt
# [Progress: 1600/5000 (32.0%)] elapsed 4.5 min
# [Progress: 1700/5000 (34.0%)] elapsed 4.8 min
# [Progress: 1800/5000 (36.0%)] elapsed 5.0 min
# [Progress: 1900/5000 (38.0%)] elapsed 5.3 min
# [Progress: 2000/5000 (40.0%)] elapsed 5.6 min
# Step 2000: train loss 5.3366 (ppl 207.81), val loss 5.8294 (ppl 340.16), lr 2.60e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/best.pt
# 💾 Checkpoint saved at step 2000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/checkpoint_2000.pt
# [Progress: 2100/5000 (42.0%)] elapsed 5.9 min
# [Progress: 2200/5000 (44.0%)] elapsed 6.2 min
# [Progress: 2300/5000 (46.0%)] elapsed 6.4 min
# [Progress: 2400/5000 (48.0%)] elapsed 6.7 min
# [Progress: 2500/5000 (50.0%)] elapsed 7.0 min
# Step 2500: train loss 5.2245 (ppl 185.77), val loss 5.7827 (ppl 324.64), lr 2.17e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/best.pt
# 💾 Checkpoint saved at step 2500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/checkpoint_2500.pt
# [Progress: 2600/5000 (52.0%)] elapsed 7.3 min
# [Progress: 2700/5000 (54.0%)] elapsed 7.6 min
# [Progress: 2800/5000 (56.0%)] elapsed 7.8 min
# [Progress: 2900/5000 (58.0%)] elapsed 8.1 min
# [Progress: 3000/5000 (60.0%)] elapsed 8.4 min
# Step 3000: train loss 5.1347 (ppl 169.81), val loss 5.7272 (ppl 307.12), lr 1.65e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/best.pt
# 💾 Checkpoint saved at step 3000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/checkpoint_3000.pt
# [Progress: 3100/5000 (62.0%)] elapsed 8.7 min
# [Progress: 3200/5000 (64.0%)] elapsed 9.0 min
# [Progress: 3300/5000 (66.0%)] elapsed 9.2 min
# [Progress: 3400/5000 (68.0%)] elapsed 9.5 min
# [Progress: 3500/5000 (70.0%)] elapsed 9.8 min
# Step 3500: train loss 5.0845 (ppl 161.50), val loss 5.7015 (ppl 299.30), lr 1.13e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/best.pt
# 💾 Checkpoint saved at step 3500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/checkpoint_3500.pt
# [Progress: 3600/5000 (72.0%)] elapsed 10.1 min
# [Progress: 3700/5000 (74.0%)] elapsed 10.4 min
# [Progress: 3800/5000 (76.0%)] elapsed 10.6 min
# [Progress: 3900/5000 (78.0%)] elapsed 10.9 min
# [Progress: 4000/5000 (80.0%)] elapsed 11.2 min
# Step 4000: train loss 5.0486 (ppl 155.80), val loss 5.7012 (ppl 299.23), lr 6.95e-05
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/best.pt
# 💾 Checkpoint saved at step 4000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/checkpoint_4000.pt
# [Progress: 4100/5000 (82.0%)] elapsed 11.5 min
# [Progress: 4200/5000 (84.0%)] elapsed 11.8 min
# [Progress: 4300/5000 (86.0%)] elapsed 12.0 min
# [Progress: 4400/5000 (88.0%)] elapsed 12.3 min
# [Progress: 4500/5000 (90.0%)] elapsed 12.6 min
# Step 4500: train loss 5.0240 (ppl 152.02), val loss 5.6775 (ppl 292.21), lr 4.03e-05
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/best.pt
# 💾 Checkpoint saved at step 4500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/checkpoint_4500.pt
# [Progress: 4600/5000 (92.0%)] elapsed 12.9 min
# [Progress: 4700/5000 (94.0%)] elapsed 13.2 min
# [Progress: 4800/5000 (96.0%)] elapsed 13.4 min
# [Progress: 4900/5000 (98.0%)] elapsed 13.7 min
# Step 4999: train loss 4.9979 (ppl 148.10), val loss 5.6975 (ppl 298.12), lr 3.00e-05
# ✅ Final model saved to /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/gpt_final.pt
# 🌟 Loaded best checkpoint for generation: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_024627/checkpoints/best.pt
# 📝 Sample:
#  2 0 - सौ रुपये मिलते है । रुपये मिलें - पाँच रुपये दे - रुपये से रुपये दे दे थे ।
#
# 📦 Zipping checkpoints for download...
# ✅ Run this in a new cell to download:
#    from google.colab import files
#    files.download('checkpoints.zip')

# %% [markdown]
# **2) MultiQuery Attention**

# %%
import os
import math
import time
import torch
import torch.nn as nn
from torch.nn import functional as F
from dataclasses import dataclass
from typing import Optional
from tokenizers import Tokenizer, models, trainers, pre_tokenizers
from tokenizers.processors import TemplateProcessing

# ---------------------
# Reproducibility
# ---------------------
torch.manual_seed(1337)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# ---------------------
# Config
# ---------------------
@dataclass
class Config:
    # data
    dataset_path: str = "dataset/new_input.txt"
    tokenizer_dir: str = "tokenizer"
    tokenizer_file: str = "tokenizer/bpe_tokenizer.json"
    vocab_size: int = 8000 # changed from 10000
    force_retrain_tokenizer: bool = False  # set True to retrain with ByteLevel BPE
    dataset_token_limit: Optional[int] = 1_500_000  # NEW: faster runs
    # model
    n_embd: int = 320               # CHANGED: 384 -> 320 (faster)
    n_head: int = 6
    n_layer: int = 3                # CHANGED: 4 -> 3 (faster)
    dropout: float = 0.5            # stronger regularization
    emb_dropout: float = 0.1        # new: embedding dropout
    block_size: int = 256
    # attention selection
    attn_type: str = "mqa"        # NEW: "mha" | "mqa" | "gqa" | "mlha"
    num_kv_heads: int = 1         # NEW: for MQA/GQA (MQA=1, GQA>1 and divides n_head)
    latent_kv_heads: int = 2      # NEW: for MLHA (# latent K/V heads)
    # training
    batch_size: int = 32 # changed from 64
    max_iters: int = 5000 # changed from 25000 for faster runs
    eval_interval: int = 500      # CHANGED: 1000 -> 500
    eval_iters: int = 50 # changed from 200
    learning_rate: float = 3e-4
    min_lr: float = 3e-5
    warmup_iters: int = 1000      # CHANGED: 2000 -> 1000
    weight_decay: float = 0.1
    betas: tuple = (0.9, 0.95)
    grad_clip: float = 1.0
    grad_accum_steps: int = 2 # changed from 1
    use_amp: bool = True
    patience_evals: int = 6        # new: early stopping patience
    save_every: int = 500
    ckpt_dir: str = "checkpoints"
    resume_path: Optional[str] = None
    use_best_for_generation: bool = True   # NEW
    # loss
    label_smoothing: float = 0.1   # new: improves generalization
    # generation
    gen_max_new_tokens: int = 700
    gen_temperature: float = 1.0
    gen_top_k: int = 50

cfg = Config()
# === [NEW] Set up Drive output directories ===
import datetime
run_id = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
drive_root = f"/content/drive/MyDrive/gpt_from_scratch_runs/run_{run_id}"

cfg.ckpt_dir = os.path.join(drive_root, "checkpoints")
cfg.tokenizer_dir = os.path.join(drive_root, "tokenizer")
cfg.tokenizer_file = os.path.join(cfg.tokenizer_dir, "bpe_tokenizer.json")
os.makedirs(cfg.ckpt_dir, exist_ok=True)
os.makedirs(cfg.tokenizer_dir, exist_ok=True)

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# ---------------------
# Clone dataset repo (COLAB)
# ---------------------
if not os.path.exists(cfg.dataset_path):
    print("📥 Cloning dataset repo...")
    os.system("git clone https://github.com/DevashishXO/GPT-From-Scratch.git")
    os.chdir("GPT-From-Scratch")
else:
    print("✅ Dataset already exists.")

# ---------------------
# Tokenizer setup
# ---------------------
os.makedirs(cfg.tokenizer_dir, exist_ok=True)

def train_or_load_tokenizer():
    tok_path = cfg.tokenizer_file
    if cfg.force_retrain_tokenizer and os.path.exists(tok_path):
        print("♻️ Forcing tokenizer retrain, removing old file...")
        try:
            os.remove(tok_path)
        except FileNotFoundError:
            pass

    if not os.path.exists(tok_path):
        print("🔧 Training new BPE tokenizer...")
        tokenizer = Tokenizer(models.BPE(unk_token="[UNK]"))
        # ByteLevel is more robust for multilingual/raw punctuation; switch if retraining
        tokenizer.pre_tokenizer = pre_tokenizers.ByteLevel() if cfg.force_retrain_tokenizer else pre_tokenizers.Whitespace()
        trainer = trainers.BpeTrainer(
            vocab_size=cfg.vocab_size,
            special_tokens=["[PAD]", "[UNK]", "[BOS]", "[EOS]"]
        )
        tokenizer.train([cfg.dataset_path], trainer)
        if isinstance(tokenizer.model, models.BPE):
            tokenizer.model.unk_token = "[UNK]"
        bos_id = tokenizer.token_to_id("[BOS]")
        eos_id = tokenizer.token_to_id("[EOS]")
        tokenizer.post_processor = TemplateProcessing(
            single="[BOS] $A [EOS]",
            pair="[BOS] $A [EOS] [BOS] $B [EOS]",
            special_tokens=[("[BOS]", bos_id), ("[EOS]", eos_id)]
        )
        tokenizer.save(tok_path)
        print("✅ Tokenizer trained and saved.")
    else:
        print("✅ Existing tokenizer found. Loading...")
    tokenizer = Tokenizer.from_file(tok_path)
    if isinstance(tokenizer.model, models.BPE) and tokenizer.model.unk_token is None:
        tokenizer.model.unk_token = "[UNK]"
    bos_id = tokenizer.token_to_id("[BOS]")
    eos_id = tokenizer.token_to_id("[EOS]")
    if tokenizer.post_processor is None:
        tokenizer.post_processor = TemplateProcessing(
            single="[BOS] $A [EOS]",
            pair="[BOS] $A [EOS] [BOS] $B [EOS]",
            special_tokens=[("[BOS]", bos_id), ("[EOS]", eos_id)]
        )
    return tokenizer

tokenizer = train_or_load_tokenizer()
vocab_size = tokenizer.get_vocab_size()
print(f"📊 Vocab size: {vocab_size}")

BOS_ID = tokenizer.token_to_id("[BOS]")
EOS_ID = tokenizer.token_to_id("[EOS]")

def encode_text_stream_with_boundaries(txt: str) -> list[int]:
    ids: list[int] = []
    for line in txt.splitlines():
        line = line.strip()
        if not line:
            continue
        ids.extend(tokenizer.encode(line).ids)  # post-processor injects BOS/EOS
    return ids

def decode_ids(ids: list[int]) -> str:
    return tokenizer.decode(ids, skip_special_tokens=True)

# ---------------------
# Load dataset
# ---------------------
with open(cfg.dataset_path, "r", encoding="utf-8") as f:
    raw_text = f.read()
print(f"📖 Dataset length (chars): {len(raw_text):,}")

all_ids = encode_text_stream_with_boundaries(raw_text)
data = torch.tensor(all_ids, dtype=torch.long)
if len(data) < cfg.block_size + 1:
    raise ValueError(f"Encoded dataset too small ({len(data)}) for block_size={cfg.block_size}")

n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

def get_batch(split: str):
    src = train_data if split == 'train' else val_data
    ix = torch.randint(0, len(src) - cfg.block_size, (cfg.batch_size,))
    x = torch.stack([src[i:i+cfg.block_size] for i in ix])
    y = torch.stack([src[i+1:i+cfg.block_size+1] for i in ix])
    return x.to(device), y.to(device)

# ---------------------
# LR schedule
# ---------------------
def cosine_lr(step: int, base_lr: float, min_lr: float, warmup: int, total: int):
    if step < warmup:
        return base_lr * step / max(1, warmup)
    progress = (step - warmup) / max(1, total - warmup)
    return min_lr + 0.5 * (base_lr - min_lr) * (1 + math.cos(math.pi * progress))

# ---------------------
# Model
# ---------------------
class Head(nn.Module):
    def __init__(self, head_size: int):
        super().__init__()
        self.key = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.query = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.value = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(cfg.block_size, cfg.block_size)))
        self.dropout = nn.Dropout(cfg.dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x); q = self.query(x)
        wei = q @ k.transpose(-2, -1) * (k.shape[-1] ** -0.5)
        # AMP-stable mask
        wei = wei.masked_fill(self.tril[:T, :T] == 0, torch.finfo(wei.dtype).min)
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        out = wei @ v
        return out

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads: int, head_size: int):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(head_size * num_heads, cfg.n_embd)
        self.dropout = nn.Dropout(cfg.dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out
    pass

# NEW: MQA/GQA/MLHA implementations (project Q/K/V once and reshape)
class MultiQueryAttention(nn.Module):
    def __init__(self, n_embd: int, n_head: int, kv_heads: int):
        super().__init__()
        assert n_head % kv_heads == 0, "n_head must be divisible by kv_heads"
        self.n_head = n_head
        self.kv_heads = kv_heads
        self.head_size = n_embd // n_head
        self.q_proj = nn.Linear(n_embd, n_head * self.head_size, bias=False)
        self.k_proj = nn.Linear(n_embd, kv_heads * self.head_size, bias=False)
        self.v_proj = nn.Linear(n_embd, kv_heads * self.head_size, bias=False)
        self.proj = nn.Linear(n_head * self.head_size, n_embd)
        self.dropout = nn.Dropout(cfg.dropout)
        self.register_buffer('tril', torch.tril(torch.ones(cfg.block_size, cfg.block_size)))

    def forward(self, x):
        B, T, C = x.shape
        q = self.q_proj(x).view(B, T, self.n_head, self.head_size).transpose(1, 2)  # (B,H,T,dh)
        k = self.k_proj(x).view(B, T, self.kv_heads, self.head_size).transpose(1, 2)  # (B,KV,T,dh)
        v = self.v_proj(x).view(B, T, self.kv_heads, self.head_size).transpose(1, 2)  # (B,KV,T,dh)

        if self.kv_heads != self.n_head:
            repeat = self.n_head // self.kv_heads
            k = k.repeat_interleave(repeat, dim=1)  # (B,H,T,dh)
            v = v.repeat_interleave(repeat, dim=1)  # (B,H,T,dh)

        att = (q @ k.transpose(-2, -1)) * (self.head_size ** -0.5)  # (B,H,T,T)
        att = att.masked_fill(self.tril[:T, :T] == 0, torch.finfo(att.dtype).min)
        att = F.softmax(att, dim=-1)
        att = self.dropout(att)
        out = att @ v  # (B,H,T,dh)
        out = out.transpose(1, 2).contiguous().view(B, T, self.n_head * self.head_size)
        return self.dropout(self.proj(out))

class MultiHeadLatentAttention(nn.Module):
    def __init__(self, n_embd: int, n_head: int, latent_heads: int):
        super().__init__()
        assert n_head >= 1 and latent_heads >= 1
        self.n_head = n_head
        self.latent_heads = latent_heads
        self.head_size = n_embd // n_head
        self.q_proj = nn.Linear(n_embd, n_head * self.head_size, bias=False)
        self.k_lat_proj = nn.Linear(n_embd, latent_heads * self.head_size, bias=False)
        self.v_lat_proj = nn.Linear(n_embd, latent_heads * self.head_size, bias=False)
        # mixing matrix to map latent heads -> per-head K/V
        self.mix = nn.Parameter(torch.empty(n_head, latent_heads))
        nn.init.normal_(self.mix, mean=0.0, std=1.0 / max(1, latent_heads))
        self.proj = nn.Linear(n_head * self.head_size, n_embd)
        self.dropout = nn.Dropout(cfg.dropout)
        self.register_buffer('tril', torch.tril(torch.ones(cfg.block_size, cfg.block_size)))

    def forward(self, x):
        B, T, C = x.shape
        q = self.q_proj(x).view(B, T, self.n_head, self.head_size).transpose(1, 2)  # (B,H,T,dh)
        k_lat = self.k_lat_proj(x).view(B, T, self.latent_heads, self.head_size).transpose(1, 2)  # (B,L,T,dh)
        v_lat = self.v_lat_proj(x).view(B, T, self.latent_heads, self.head_size).transpose(1, 2)  # (B,L,T,dh)

        w = torch.softmax(self.mix, dim=-1)  # (H,L)
        # mix latent K/V into per-head K/V
        k = torch.einsum("bltd,hl->bhtd", k_lat, w)  # (B,H,T,dh)
        v = torch.einsum("bltd,hl->bhtd", v_lat, w)  # (B,H,T,dh)

        att = (q @ k.transpose(-2, -1)) * (self.head_size ** -0.5)  # (B,H,T,T)
        att = att.masked_fill(self.tril[:T, :T] == 0, torch.finfo(att.dtype).min)
        att = F.softmax(att, dim=-1)
        att = self.dropout(att)
        out = att @ v  # (B,H,T,dh)
        out = out.transpose(1, 2).contiguous().view(B, T, self.n_head * self.head_size)
        return self.dropout(self.proj(out))

class FeedForward(nn.Module):
    def __init__(self, n_embd: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.GELU(),  # GELU generally improves GPTs
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(cfg.dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    def __init__(self, n_embd: int, n_head: int):
        super().__init__()
        head_size = n_embd // n_head
# SELECT ATTENTION HERE
        if cfg.attn_type == "mha":
            self.sa = MultiHeadAttention(n_head, head_size)
        elif cfg.attn_type == "mqa":
            self.sa = MultiQueryAttention(n_embd=n_embd, n_head=n_head, kv_heads=1)
        elif cfg.attn_type == "gqa":
            self.sa = MultiQueryAttention(n_embd=n_embd, n_head=n_head, kv_heads=cfg.num_kv_heads)
        elif cfg.attn_type == "mlha":
            self.sa = MultiHeadLatentAttention(n_embd=n_embd, n_head=n_head, latent_heads=cfg.latent_kv_heads)
        else:
            raise ValueError(f"Unknown attn_type: {cfg.attn_type}")
        self.ff = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ff(self.ln2(x))
        return x

class GPTLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, cfg.n_embd)
        self.position_embedding_table = nn.Embedding(cfg.block_size, cfg.n_embd)
        self.drop_emb = nn.Dropout(cfg.emb_dropout)  # new: embedding dropout
        self.blocks = nn.Sequential(*[Block(cfg.n_embd, cfg.n_head) for _ in range(cfg.n_layer)])
        self.ln_f = nn.LayerNorm(cfg.n_embd)
        self.lm_head = nn.Linear(cfg.n_embd, vocab_size, bias=False)
        self.apply(self._init_weights)
        self.tie_weights()

    def tie_weights(self):
        self.lm_head.weight = self.token_embedding_table.weight

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=idx.device))
        x = self.drop_emb(tok_emb + pos_emb)  # apply embedding dropout
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)
        loss = None
        if targets is not None:
            loss = F.cross_entropy(
                logits.view(B*T, -1),
                targets.view(B*T),
                label_smoothing=cfg.label_smoothing,  # new: label smoothing
            )
        return logits, loss

    @torch.no_grad()
    def _sample_next(self, logits_last, temperature=1.0, top_k=50):
        if temperature != 1.0:
            logits_last = logits_last / temperature
        probs = F.softmax(logits_last, dim=-1)
        if top_k is not None and top_k > 0:
            v, ix = torch.topk(probs, top_k)
            mask = torch.ones_like(probs, dtype=torch.bool)
            mask.scatter_(1, ix, False)
            probs = probs.masked_fill(mask, 0)
            probs = probs / probs.sum(dim=-1, keepdim=True)
        next_token = torch.multinomial(probs, num_samples=1)
        return next_token

    @torch.no_grad()
    def generate(self, idx, max_new_tokens, temperature=1.0, top_k=50, eos_id: int | None = None):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -cfg.block_size:]
            logits, _ = self(idx_cond)
            next_token = self._sample_next(logits[:, -1, :], temperature, top_k)
            idx = torch.cat((idx, next_token), dim=1)
            if eos_id is not None and (next_token == eos_id).all():
                break
        return idx

# ---------------------
# Init model/opt/amp
# ---------------------
model = GPTLanguageModel().to(device)

# AdamW param groups: no weight decay on LayerNorm or bias
decay = []
no_decay = []
for name, param in model.named_parameters():
    if name.endswith('bias') or 'ln' in name or 'norm' in name:
        no_decay.append(param)
    else:
        decay.append(param)

optim_groups = [
    {"params": decay, "weight_decay": cfg.weight_decay},
    {"params": no_decay, "weight_decay": 0.0},
]

optimizer = torch.optim.AdamW(
    optim_groups,
    lr=cfg.learning_rate,
    betas=cfg.betas
)

# Use new torch.amp API (fixes deprecation warnings)
scaler = torch.amp.GradScaler('cuda', enabled=(cfg.use_amp and device == 'cuda'))

param_millions = sum(p.numel() for p in model.parameters())/1e6
print(f"🤖 Model parameters: {param_millions:.2f} M")

os.makedirs(cfg.ckpt_dir, exist_ok=True)

start_iter = 0
best_val_loss = float('inf')
no_improve_evals = 0
if cfg.resume_path is not None and os.path.exists(cfg.resume_path):
    ckpt = torch.load(cfg.resume_path, map_location=device)
    model.load_state_dict(ckpt['model'])
    optimizer.load_state_dict(ckpt['opt'])
    start_iter = ckpt.get('iter', 0) + 1
    best_val_loss = ckpt.get('val_loss', float('inf'))
    print(f"🔄 Resumed from {cfg.resume_path} at iter {start_iter}, best_val_loss={best_val_loss:.4f}")

@torch.no_grad()
def estimate_metrics():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(cfg.eval_iters, device=device)
        for k in range(cfg.eval_iters):
            X, Y = get_batch(split)
            with torch.amp.autocast('cuda', enabled=(cfg.use_amp and device == 'cuda')):
                _, loss = model(X, Y)
            losses[k] = loss
        mean_loss = losses.mean().item()
        out[split] = {'loss': mean_loss, 'ppl': math.exp(mean_loss)}
    model.train()
    return out

# ---------------------
# Training
# ---------------------
t0 = time.time()
for iter in range(start_iter, cfg.max_iters):
    lr = cosine_lr(iter, cfg.learning_rate, cfg.min_lr, cfg.warmup_iters, cfg.max_iters)
    for g in optimizer.param_groups:
        g['lr'] = lr

    if iter % 100 == 0 and iter > 0:
        elapsed = time.time() - t0
        print(f"[Progress: {iter}/{cfg.max_iters} ({100*iter/cfg.max_iters:.1f}%)] elapsed {elapsed/60:.1f} min")

    if iter % cfg.eval_interval == 0 or iter == cfg.max_iters - 1:
        metrics = estimate_metrics()
        print(f"Step {iter}: train loss {metrics['train']['loss']:.4f} (ppl {metrics['train']['ppl']:.2f}), "
              f"val loss {metrics['val']['loss']:.4f} (ppl {metrics['val']['ppl']:.2f}), lr {lr:.2e}")
        if metrics['val']['loss'] + 1e-6 < best_val_loss:
            best_val_loss = metrics['val']['loss']
            no_improve_evals = 0
            best_path = os.path.join(cfg.ckpt_dir, "best.pt")
            torch.save({'iter': iter, 'model': model.state_dict(), 'opt': optimizer.state_dict(),
                        'val_loss': best_val_loss, 'cfg': cfg.__dict__}, best_path)
            print(f" -> 💾 Best checkpoint updated: {best_path}")
        else:
            no_improve_evals += 1
            if no_improve_evals >= cfg.patience_evals:
                print(f"⏹️ Early stopping after {no_improve_evals} evals without val improvement.")
                break

    optimizer.zero_grad(set_to_none=True)
    for micro in range(cfg.grad_accum_steps):
        xb, yb = get_batch('train')
        with torch.amp.autocast('cuda', enabled=(cfg.use_amp and device == 'cuda')):
            _, loss = model(xb, yb)
            loss = loss / cfg.grad_accum_steps
        scaler.scale(loss).backward()

    if cfg.grad_clip and cfg.grad_clip > 0:
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)

    scaler.step(optimizer)
    scaler.update()

    if iter > 0 and iter % cfg.save_every == 0:
        ckpt_path = os.path.join(cfg.ckpt_dir, f"checkpoint_{iter}.pt")
        torch.save({'iter': iter, 'model': model.state_dict(), 'opt': optimizer.state_dict(),
                    'val_loss': best_val_loss, 'cfg': cfg.__dict__}, ckpt_path)
        print(f"💾 Checkpoint saved at step {iter}: {ckpt_path}")

# ---------------------
# Save final, generate sample
# ---------------------
final_model_path = os.path.join(cfg.ckpt_dir, "gpt_final.pt")
torch.save(model.state_dict(), final_model_path)
print(f"✅ Final model saved to {final_model_path}")

# NEW: optionally reload best.pt for generation
best_path = os.path.join(cfg.ckpt_dir, "best.pt")
if cfg.use_best_for_generation and os.path.exists(best_path):
    try:
        ckpt = torch.load(best_path, map_location=device)
        model.load_state_dict(ckpt["model"])
        print(f"🌟 Loaded best checkpoint for generation: {best_path}")
    except Exception as e:
        print(f"⚠️ Could not load best.pt for generation: {e}")

context = torch.tensor([[BOS_ID]], dtype=torch.long, device=device)
generated_ids = model.generate(
    context,
    max_new_tokens=cfg.gen_max_new_tokens,
    temperature=cfg.gen_temperature,
    top_k=cfg.gen_top_k,
    eos_id=EOS_ID
)[0].tolist()
print("📝 Sample:\n", decode_ids(generated_ids))

# ---------------------
# Zip checkpoints for download (COLAB)
# ---------------------
print("\n📦 Zipping checkpoints for download...")
os.system(f"zip -r checkpoints.zip {cfg.ckpt_dir}")
print("✅ Run this in a new cell to download:")
print("   from google.colab import files")
print("   files.download('checkpoints.zip')")
# Out:
# ✅ Dataset already exists.
# 🔧 Training new BPE tokenizer...
# ✅ Tokenizer trained and saved.
# 📊 Vocab size: 8000
# 📖 Dataset length (chars): 6,793,953
# 🤖 Model parameters: 5.82 M
# Step 0: train loss 9.0532 (ppl 8545.88), val loss 9.0506 (ppl 8523.57), lr 0.00e+00
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/best.pt
# [Progress: 100/5000 (2.0%)] elapsed 0.2 min
# [Progress: 200/5000 (4.0%)] elapsed 0.4 min
# [Progress: 300/5000 (6.0%)] elapsed 0.6 min
# [Progress: 400/5000 (8.0%)] elapsed 0.8 min
# [Progress: 500/5000 (10.0%)] elapsed 1.0 min
# Step 500: train loss 6.2552 (ppl 520.71), val loss 6.4433 (ppl 628.45), lr 1.50e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/best.pt
# 💾 Checkpoint saved at step 500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/checkpoint_500.pt
# [Progress: 600/5000 (12.0%)] elapsed 1.3 min
# [Progress: 700/5000 (14.0%)] elapsed 1.5 min
# [Progress: 800/5000 (16.0%)] elapsed 1.6 min
# [Progress: 900/5000 (18.0%)] elapsed 1.8 min
# [Progress: 1000/5000 (20.0%)] elapsed 2.0 min
# Step 1000: train loss 5.7695 (ppl 320.37), val loss 6.0801 (ppl 437.08), lr 3.00e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/best.pt
# 💾 Checkpoint saved at step 1000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/checkpoint_1000.pt
# [Progress: 1100/5000 (22.0%)] elapsed 2.3 min
# [Progress: 1200/5000 (24.0%)] elapsed 2.5 min
# [Progress: 1300/5000 (26.0%)] elapsed 2.7 min
# [Progress: 1400/5000 (28.0%)] elapsed 2.9 min
# [Progress: 1500/5000 (30.0%)] elapsed 3.1 min
# Step 1500: train loss 5.5211 (ppl 249.90), val loss 5.9501 (ppl 383.80), lr 2.90e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/best.pt
# 💾 Checkpoint saved at step 1500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/checkpoint_1500.pt
# [Progress: 1600/5000 (32.0%)] elapsed 3.3 min
# [Progress: 1700/5000 (34.0%)] elapsed 3.5 min
# [Progress: 1800/5000 (36.0%)] elapsed 3.7 min
# [Progress: 1900/5000 (38.0%)] elapsed 3.9 min
# [Progress: 2000/5000 (40.0%)] elapsed 4.1 min
# Step 2000: train loss 5.3558 (ppl 211.84), val loss 5.8408 (ppl 344.07), lr 2.60e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/best.pt
# 💾 Checkpoint saved at step 2000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/checkpoint_2000.pt
# [Progress: 2100/5000 (42.0%)] elapsed 4.3 min
# [Progress: 2200/5000 (44.0%)] elapsed 4.5 min
# [Progress: 2300/5000 (46.0%)] elapsed 4.7 min
# [Progress: 2400/5000 (48.0%)] elapsed 4.9 min
# [Progress: 2500/5000 (50.0%)] elapsed 5.1 min
# Step 2500: train loss 5.2315 (ppl 187.07), val loss 5.7821 (ppl 324.44), lr 2.17e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/best.pt
# 💾 Checkpoint saved at step 2500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/checkpoint_2500.pt
# [Progress: 2600/5000 (52.0%)] elapsed 5.3 min
# [Progress: 2700/5000 (54.0%)] elapsed 5.5 min
# [Progress: 2800/5000 (56.0%)] elapsed 5.7 min
# [Progress: 2900/5000 (58.0%)] elapsed 5.9 min
# [Progress: 3000/5000 (60.0%)] elapsed 6.1 min
# Step 3000: train loss 5.1536 (ppl 173.05), val loss 5.7571 (ppl 316.43), lr 1.65e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/best.pt
# 💾 Checkpoint saved at step 3000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/checkpoint_3000.pt
# [Progress: 3100/5000 (62.0%)] elapsed 6.4 min
# [Progress: 3200/5000 (64.0%)] elapsed 6.6 min
# [Progress: 3300/5000 (66.0%)] elapsed 6.8 min
# [Progress: 3400/5000 (68.0%)] elapsed 7.0 min
# [Progress: 3500/5000 (70.0%)] elapsed 7.2 min
# Step 3500: train loss 5.1038 (ppl 164.64), val loss 5.7292 (ppl 307.71), lr 1.13e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/best.pt
# 💾 Checkpoint saved at step 3500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/checkpoint_3500.pt
# [Progress: 3600/5000 (72.0%)] elapsed 7.4 min
# [Progress: 3700/5000 (74.0%)] elapsed 7.6 min
# [Progress: 3800/5000 (76.0%)] elapsed 7.8 min
# [Progress: 3900/5000 (78.0%)] elapsed 8.0 min
# [Progress: 4000/5000 (80.0%)] elapsed 8.2 min
# Step 4000: train loss 5.0605 (ppl 157.67), val loss 5.7060 (ppl 300.68), lr 6.95e-05
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/best.pt
# 💾 Checkpoint saved at step 4000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/checkpoint_4000.pt
# [Progress: 4100/5000 (82.0%)] elapsed 8.4 min
# [Progress: 4200/5000 (84.0%)] elapsed 8.6 min
# [Progress: 4300/5000 (86.0%)] elapsed 8.8 min
# [Progress: 4400/5000 (88.0%)] elapsed 9.0 min
# [Progress: 4500/5000 (90.0%)] elapsed 9.2 min
# Step 4500: train loss 5.0381 (ppl 154.17), val loss 5.6866 (ppl 294.90), lr 4.03e-05
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/best.pt
# 💾 Checkpoint saved at step 4500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/checkpoint_4500.pt
# [Progress: 4600/5000 (92.0%)] elapsed 9.4 min
# [Progress: 4700/5000 (94.0%)] elapsed 9.6 min
# [Progress: 4800/5000 (96.0%)] elapsed 9.8 min
# [Progress: 4900/5000 (98.0%)] elapsed 10.0 min
# Step 4999: train loss 5.0203 (ppl 151.45), val loss 5.6823 (ppl 293.62), lr 3.00e-05
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/best.pt
# ✅ Final model saved to /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/gpt_final.pt
# 🌟 Loaded best checkpoint for generation: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_030333/checkpoints/best.pt
# 📝 Sample:
#  मिस जोशी -' आपकी पत्नी , यह बात है कि यह रोग से कह दीजिए कि यह तो मुझे विश्वास दिलाता हो ।’ मगर आप जो कुछ भी कुछ सेवा का कारण क्या है ? हम भी आपकी स्त्री पर लज्जित हो जाय । क्या ? आप के स्वामी , और भी आपकी निगाह रहती हैं । '
#
# 📦 Zipping checkpoints for download...
# ✅ Run this in a new cell to download:
#    from google.colab import files
#    files.download('checkpoints.zip')

# %% [markdown]
# **3) Grouped Query Attention**

# %%
import os
import math
import time
import torch
import torch.nn as nn
from torch.nn import functional as F
from dataclasses import dataclass
from typing import Optional
from tokenizers import Tokenizer, models, trainers, pre_tokenizers
from tokenizers.processors import TemplateProcessing

# ---------------------
# Reproducibility
# ---------------------
torch.manual_seed(1337)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# ---------------------
# Config
# ---------------------
@dataclass
class Config:
    # data
    dataset_path: str = "dataset/new_input.txt"
    tokenizer_dir: str = "tokenizer"
    tokenizer_file: str = "tokenizer/bpe_tokenizer.json"
    vocab_size: int = 8000 # changed from 10000
    force_retrain_tokenizer: bool = False  # set True to retrain with ByteLevel BPE
    dataset_token_limit: Optional[int] = 1_500_000  # NEW: faster runs
    # model
    n_embd: int = 320               # CHANGED: 384 -> 320 (faster)
    n_head: int = 6
    n_layer: int = 3                # CHANGED: 4 -> 3 (faster)
    dropout: float = 0.5            # stronger regularization
    emb_dropout: float = 0.1        # new: embedding dropout
    block_size: int = 256
    # attention selection
    attn_type: str = "gqa"        # NEW: "mha" | "mqa" | "gqa" | "mlha"
    num_kv_heads: int = 3         # NEW: for MQA/GQA (MQA=1, GQA>1 and divides n_head)
    latent_kv_heads: int = 2      # NEW: for MLHA (# latent K/V heads)
    # training
    batch_size: int = 32 # changed from 64
    max_iters: int = 5000 # changed from 25000 for faster runs
    eval_interval: int = 500      # CHANGED: 1000 -> 500
    eval_iters: int = 50 # changed from 200
    learning_rate: float = 3e-4
    min_lr: float = 3e-5
    warmup_iters: int = 1000      # CHANGED: 2000 -> 1000
    weight_decay: float = 0.1
    betas: tuple = (0.9, 0.95)
    grad_clip: float = 1.0
    grad_accum_steps: int = 2 # changed from 1
    use_amp: bool = True
    patience_evals: int = 6        # new: early stopping patience
    save_every: int = 500
    ckpt_dir: str = "checkpoints"
    resume_path: Optional[str] = None
    use_best_for_generation: bool = True   # NEW
    # loss
    label_smoothing: float = 0.1   # new: improves generalization
    # generation
    gen_max_new_tokens: int = 700
    gen_temperature: float = 1.0
    gen_top_k: int = 50

cfg = Config()
# === [NEW] Set up Drive output directories ===
import datetime
run_id = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
drive_root = f"/content/drive/MyDrive/gpt_from_scratch_runs/run_{run_id}"

cfg.ckpt_dir = os.path.join(drive_root, "checkpoints")
cfg.tokenizer_dir = os.path.join(drive_root, "tokenizer")
cfg.tokenizer_file = os.path.join(cfg.tokenizer_dir, "bpe_tokenizer.json")
os.makedirs(cfg.ckpt_dir, exist_ok=True)
os.makedirs(cfg.tokenizer_dir, exist_ok=True)

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# ---------------------
# Clone dataset repo (COLAB)
# ---------------------
if not os.path.exists(cfg.dataset_path):
    print("📥 Cloning dataset repo...")
    os.system("git clone https://github.com/DevashishXO/GPT-From-Scratch.git")
    os.chdir("GPT-From-Scratch")
else:
    print("✅ Dataset already exists.")

# ---------------------
# Tokenizer setup
# ---------------------
os.makedirs(cfg.tokenizer_dir, exist_ok=True)

def train_or_load_tokenizer():
    tok_path = cfg.tokenizer_file
    if cfg.force_retrain_tokenizer and os.path.exists(tok_path):
        print("♻️ Forcing tokenizer retrain, removing old file...")
        try:
            os.remove(tok_path)
        except FileNotFoundError:
            pass

    if not os.path.exists(tok_path):
        print("🔧 Training new BPE tokenizer...")
        tokenizer = Tokenizer(models.BPE(unk_token="[UNK]"))
        # ByteLevel is more robust for multilingual/raw punctuation; switch if retraining
        tokenizer.pre_tokenizer = pre_tokenizers.ByteLevel() if cfg.force_retrain_tokenizer else pre_tokenizers.Whitespace()
        trainer = trainers.BpeTrainer(
            vocab_size=cfg.vocab_size,
            special_tokens=["[PAD]", "[UNK]", "[BOS]", "[EOS]"]
        )
        tokenizer.train([cfg.dataset_path], trainer)
        if isinstance(tokenizer.model, models.BPE):
            tokenizer.model.unk_token = "[UNK]"
        bos_id = tokenizer.token_to_id("[BOS]")
        eos_id = tokenizer.token_to_id("[EOS]")
        tokenizer.post_processor = TemplateProcessing(
            single="[BOS] $A [EOS]",
            pair="[BOS] $A [EOS] [BOS] $B [EOS]",
            special_tokens=[("[BOS]", bos_id), ("[EOS]", eos_id)]
        )
        tokenizer.save(tok_path)
        print("✅ Tokenizer trained and saved.")
    else:
        print("✅ Existing tokenizer found. Loading...")
    tokenizer = Tokenizer.from_file(tok_path)
    if isinstance(tokenizer.model, models.BPE) and tokenizer.model.unk_token is None:
        tokenizer.model.unk_token = "[UNK]"
    bos_id = tokenizer.token_to_id("[BOS]")
    eos_id = tokenizer.token_to_id("[EOS]")
    if tokenizer.post_processor is None:
        tokenizer.post_processor = TemplateProcessing(
            single="[BOS] $A [EOS]",
            pair="[BOS] $A [EOS] [BOS] $B [EOS]",
            special_tokens=[("[BOS]", bos_id), ("[EOS]", eos_id)]
        )
    return tokenizer

tokenizer = train_or_load_tokenizer()
vocab_size = tokenizer.get_vocab_size()
print(f"📊 Vocab size: {vocab_size}")

BOS_ID = tokenizer.token_to_id("[BOS]")
EOS_ID = tokenizer.token_to_id("[EOS]")

def encode_text_stream_with_boundaries(txt: str) -> list[int]:
    ids: list[int] = []
    for line in txt.splitlines():
        line = line.strip()
        if not line:
            continue
        ids.extend(tokenizer.encode(line).ids)  # post-processor injects BOS/EOS
    return ids

def decode_ids(ids: list[int]) -> str:
    return tokenizer.decode(ids, skip_special_tokens=True)

# ---------------------
# Load dataset
# ---------------------
with open(cfg.dataset_path, "r", encoding="utf-8") as f:
    raw_text = f.read()
print(f"📖 Dataset length (chars): {len(raw_text):,}")

all_ids = encode_text_stream_with_boundaries(raw_text)
data = torch.tensor(all_ids, dtype=torch.long)
if len(data) < cfg.block_size + 1:
    raise ValueError(f"Encoded dataset too small ({len(data)}) for block_size={cfg.block_size}")

n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

def get_batch(split: str):
    src = train_data if split == 'train' else val_data
    ix = torch.randint(0, len(src) - cfg.block_size, (cfg.batch_size,))
    x = torch.stack([src[i:i+cfg.block_size] for i in ix])
    y = torch.stack([src[i+1:i+cfg.block_size+1] for i in ix])
    return x.to(device), y.to(device)

# ---------------------
# LR schedule
# ---------------------
def cosine_lr(step: int, base_lr: float, min_lr: float, warmup: int, total: int):
    if step < warmup:
        return base_lr * step / max(1, warmup)
    progress = (step - warmup) / max(1, total - warmup)
    return min_lr + 0.5 * (base_lr - min_lr) * (1 + math.cos(math.pi * progress))

# ---------------------
# Model
# ---------------------
class Head(nn.Module):
    def __init__(self, head_size: int):
        super().__init__()
        self.key = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.query = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.value = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(cfg.block_size, cfg.block_size)))
        self.dropout = nn.Dropout(cfg.dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x); q = self.query(x)
        wei = q @ k.transpose(-2, -1) * (k.shape[-1] ** -0.5)
        # AMP-stable mask
        wei = wei.masked_fill(self.tril[:T, :T] == 0, torch.finfo(wei.dtype).min)
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        out = wei @ v
        return out

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads: int, head_size: int):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(head_size * num_heads, cfg.n_embd)
        self.dropout = nn.Dropout(cfg.dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out
    pass

# NEW: MQA/GQA/MLHA implementations (project Q/K/V once and reshape)
class MultiQueryAttention(nn.Module):
    def __init__(self, n_embd: int, n_head: int, kv_heads: int):
        super().__init__()
        assert n_head % kv_heads == 0, "n_head must be divisible by kv_heads"
        self.n_head = n_head
        self.kv_heads = kv_heads
        self.head_size = n_embd // n_head
        self.q_proj = nn.Linear(n_embd, n_head * self.head_size, bias=False)
        self.k_proj = nn.Linear(n_embd, kv_heads * self.head_size, bias=False)
        self.v_proj = nn.Linear(n_embd, kv_heads * self.head_size, bias=False)
        self.proj = nn.Linear(n_head * self.head_size, n_embd)
        self.dropout = nn.Dropout(cfg.dropout)
        self.register_buffer('tril', torch.tril(torch.ones(cfg.block_size, cfg.block_size)))

    def forward(self, x):
        B, T, C = x.shape
        q = self.q_proj(x).view(B, T, self.n_head, self.head_size).transpose(1, 2)  # (B,H,T,dh)
        k = self.k_proj(x).view(B, T, self.kv_heads, self.head_size).transpose(1, 2)  # (B,KV,T,dh)
        v = self.v_proj(x).view(B, T, self.kv_heads, self.head_size).transpose(1, 2)  # (B,KV,T,dh)

        if self.kv_heads != self.n_head:
            repeat = self.n_head // self.kv_heads
            k = k.repeat_interleave(repeat, dim=1)  # (B,H,T,dh)
            v = v.repeat_interleave(repeat, dim=1)  # (B,H,T,dh)

        att = (q @ k.transpose(-2, -1)) * (self.head_size ** -0.5)  # (B,H,T,T)
        att = att.masked_fill(self.tril[:T, :T] == 0, torch.finfo(att.dtype).min)
        att = F.softmax(att, dim=-1)
        att = self.dropout(att)
        out = att @ v  # (B,H,T,dh)
        out = out.transpose(1, 2).contiguous().view(B, T, self.n_head * self.head_size)
        return self.dropout(self.proj(out))

class MultiHeadLatentAttention(nn.Module):
    def __init__(self, n_embd: int, n_head: int, latent_heads: int):
        super().__init__()
        assert n_head >= 1 and latent_heads >= 1
        self.n_head = n_head
        self.latent_heads = latent_heads
        self.head_size = n_embd // n_head
        self.q_proj = nn.Linear(n_embd, n_head * self.head_size, bias=False)
        self.k_lat_proj = nn.Linear(n_embd, latent_heads * self.head_size, bias=False)
        self.v_lat_proj = nn.Linear(n_embd, latent_heads * self.head_size, bias=False)
        # mixing matrix to map latent heads -> per-head K/V
        self.mix = nn.Parameter(torch.empty(n_head, latent_heads))
        nn.init.normal_(self.mix, mean=0.0, std=1.0 / max(1, latent_heads))
        self.proj = nn.Linear(n_head * self.head_size, n_embd)
        self.dropout = nn.Dropout(cfg.dropout)
        self.register_buffer('tril', torch.tril(torch.ones(cfg.block_size, cfg.block_size)))

    def forward(self, x):
        B, T, C = x.shape
        q = self.q_proj(x).view(B, T, self.n_head, self.head_size).transpose(1, 2)  # (B,H,T,dh)
        k_lat = self.k_lat_proj(x).view(B, T, self.latent_heads, self.head_size).transpose(1, 2)  # (B,L,T,dh)
        v_lat = self.v_lat_proj(x).view(B, T, self.latent_heads, self.head_size).transpose(1, 2)  # (B,L,T,dh)

        w = torch.softmax(self.mix, dim=-1)  # (H,L)
        # mix latent K/V into per-head K/V
        k = torch.einsum("bltd,hl->bhtd", k_lat, w)  # (B,H,T,dh)
        v = torch.einsum("bltd,hl->bhtd", v_lat, w)  # (B,H,T,dh)

        att = (q @ k.transpose(-2, -1)) * (self.head_size ** -0.5)  # (B,H,T,T)
        att = att.masked_fill(self.tril[:T, :T] == 0, torch.finfo(att.dtype).min)
        att = F.softmax(att, dim=-1)
        att = self.dropout(att)
        out = att @ v  # (B,H,T,dh)
        out = out.transpose(1, 2).contiguous().view(B, T, self.n_head * self.head_size)
        return self.dropout(self.proj(out))

class FeedForward(nn.Module):
    def __init__(self, n_embd: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.GELU(),  # GELU generally improves GPTs
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(cfg.dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    def __init__(self, n_embd: int, n_head: int):
        super().__init__()
        head_size = n_embd // n_head
# SELECT ATTENTION HERE
        if cfg.attn_type == "mha":
            self.sa = MultiHeadAttention(n_head, head_size)
        elif cfg.attn_type == "mqa":
            self.sa = MultiQueryAttention(n_embd=n_embd, n_head=n_head, kv_heads=1)
        elif cfg.attn_type == "gqa":
            self.sa = MultiQueryAttention(n_embd=n_embd, n_head=n_head, kv_heads=cfg.num_kv_heads)
        elif cfg.attn_type == "mlha":
            self.sa = MultiHeadLatentAttention(n_embd=n_embd, n_head=n_head, latent_heads=cfg.latent_kv_heads)
        else:
            raise ValueError(f"Unknown attn_type: {cfg.attn_type}")
        self.ff = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ff(self.ln2(x))
        return x

class GPTLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, cfg.n_embd)
        self.position_embedding_table = nn.Embedding(cfg.block_size, cfg.n_embd)
        self.drop_emb = nn.Dropout(cfg.emb_dropout)  # new: embedding dropout
        self.blocks = nn.Sequential(*[Block(cfg.n_embd, cfg.n_head) for _ in range(cfg.n_layer)])
        self.ln_f = nn.LayerNorm(cfg.n_embd)
        self.lm_head = nn.Linear(cfg.n_embd, vocab_size, bias=False)
        self.apply(self._init_weights)
        self.tie_weights()

    def tie_weights(self):
        self.lm_head.weight = self.token_embedding_table.weight

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=idx.device))
        x = self.drop_emb(tok_emb + pos_emb)  # apply embedding dropout
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)
        loss = None
        if targets is not None:
            loss = F.cross_entropy(
                logits.view(B*T, -1),
                targets.view(B*T),
                label_smoothing=cfg.label_smoothing,  # new: label smoothing
            )
        return logits, loss

    @torch.no_grad()
    def _sample_next(self, logits_last, temperature=1.0, top_k=50):
        if temperature != 1.0:
            logits_last = logits_last / temperature
        probs = F.softmax(logits_last, dim=-1)
        if top_k is not None and top_k > 0:
            v, ix = torch.topk(probs, top_k)
            mask = torch.ones_like(probs, dtype=torch.bool)
            mask.scatter_(1, ix, False)
            probs = probs.masked_fill(mask, 0)
            probs = probs / probs.sum(dim=-1, keepdim=True)
        next_token = torch.multinomial(probs, num_samples=1)
        return next_token

    @torch.no_grad()
    def generate(self, idx, max_new_tokens, temperature=1.0, top_k=50, eos_id: int | None = None):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -cfg.block_size:]
            logits, _ = self(idx_cond)
            next_token = self._sample_next(logits[:, -1, :], temperature, top_k)
            idx = torch.cat((idx, next_token), dim=1)
            if eos_id is not None and (next_token == eos_id).all():
                break
        return idx

# ---------------------
# Init model/opt/amp
# ---------------------
model = GPTLanguageModel().to(device)

# AdamW param groups: no weight decay on LayerNorm or bias
decay = []
no_decay = []
for name, param in model.named_parameters():
    if name.endswith('bias') or 'ln' in name or 'norm' in name:
        no_decay.append(param)
    else:
        decay.append(param)

optim_groups = [
    {"params": decay, "weight_decay": cfg.weight_decay},
    {"params": no_decay, "weight_decay": 0.0},
]

optimizer = torch.optim.AdamW(
    optim_groups,
    lr=cfg.learning_rate,
    betas=cfg.betas
)

# Use new torch.amp API (fixes deprecation warnings)
scaler = torch.amp.GradScaler('cuda', enabled=(cfg.use_amp and device == 'cuda'))

param_millions = sum(p.numel() for p in model.parameters())/1e6
print(f"🤖 Model parameters: {param_millions:.2f} M")

os.makedirs(cfg.ckpt_dir, exist_ok=True)

start_iter = 0
best_val_loss = float('inf')
no_improve_evals = 0
if cfg.resume_path is not None and os.path.exists(cfg.resume_path):
    ckpt = torch.load(cfg.resume_path, map_location=device)
    model.load_state_dict(ckpt['model'])
    optimizer.load_state_dict(ckpt['opt'])
    start_iter = ckpt.get('iter', 0) + 1
    best_val_loss = ckpt.get('val_loss', float('inf'))
    print(f"🔄 Resumed from {cfg.resume_path} at iter {start_iter}, best_val_loss={best_val_loss:.4f}")

@torch.no_grad()
def estimate_metrics():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(cfg.eval_iters, device=device)
        for k in range(cfg.eval_iters):
            X, Y = get_batch(split)
            with torch.amp.autocast('cuda', enabled=(cfg.use_amp and device == 'cuda')):
                _, loss = model(X, Y)
            losses[k] = loss
        mean_loss = losses.mean().item()
        out[split] = {'loss': mean_loss, 'ppl': math.exp(mean_loss)}
    model.train()
    return out

# ---------------------
# Training
# ---------------------
t0 = time.time()
for iter in range(start_iter, cfg.max_iters):
    lr = cosine_lr(iter, cfg.learning_rate, cfg.min_lr, cfg.warmup_iters, cfg.max_iters)
    for g in optimizer.param_groups:
        g['lr'] = lr

    if iter % 100 == 0 and iter > 0:
        elapsed = time.time() - t0
        print(f"[Progress: {iter}/{cfg.max_iters} ({100*iter/cfg.max_iters:.1f}%)] elapsed {elapsed/60:.1f} min")

    if iter % cfg.eval_interval == 0 or iter == cfg.max_iters - 1:
        metrics = estimate_metrics()
        print(f"Step {iter}: train loss {metrics['train']['loss']:.4f} (ppl {metrics['train']['ppl']:.2f}), "
              f"val loss {metrics['val']['loss']:.4f} (ppl {metrics['val']['ppl']:.2f}), lr {lr:.2e}")
        if metrics['val']['loss'] + 1e-6 < best_val_loss:
            best_val_loss = metrics['val']['loss']
            no_improve_evals = 0
            best_path = os.path.join(cfg.ckpt_dir, "best.pt")
            torch.save({'iter': iter, 'model': model.state_dict(), 'opt': optimizer.state_dict(),
                        'val_loss': best_val_loss, 'cfg': cfg.__dict__}, best_path)
            print(f" -> 💾 Best checkpoint updated: {best_path}")
        else:
            no_improve_evals += 1
            if no_improve_evals >= cfg.patience_evals:
                print(f"⏹️ Early stopping after {no_improve_evals} evals without val improvement.")
                break

    optimizer.zero_grad(set_to_none=True)
    for micro in range(cfg.grad_accum_steps):
        xb, yb = get_batch('train')
        with torch.amp.autocast('cuda', enabled=(cfg.use_amp and device == 'cuda')):
            _, loss = model(xb, yb)
            loss = loss / cfg.grad_accum_steps
        scaler.scale(loss).backward()

    if cfg.grad_clip and cfg.grad_clip > 0:
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)

    scaler.step(optimizer)
    scaler.update()

    if iter > 0 and iter % cfg.save_every == 0:
        ckpt_path = os.path.join(cfg.ckpt_dir, f"checkpoint_{iter}.pt")
        torch.save({'iter': iter, 'model': model.state_dict(), 'opt': optimizer.state_dict(),
                    'val_loss': best_val_loss, 'cfg': cfg.__dict__}, ckpt_path)
        print(f"💾 Checkpoint saved at step {iter}: {ckpt_path}")

# ---------------------
# Save final, generate sample
# ---------------------
final_model_path = os.path.join(cfg.ckpt_dir, "gpt_final.pt")
torch.save(model.state_dict(), final_model_path)
print(f"✅ Final model saved to {final_model_path}")

# NEW: optionally reload best.pt for generation
best_path = os.path.join(cfg.ckpt_dir, "best.pt")
if cfg.use_best_for_generation and os.path.exists(best_path):
    try:
        ckpt = torch.load(best_path, map_location=device)
        model.load_state_dict(ckpt["model"])
        print(f"🌟 Loaded best checkpoint for generation: {best_path}")
    except Exception as e:
        print(f"⚠️ Could not load best.pt for generation: {e}")

context = torch.tensor([[BOS_ID]], dtype=torch.long, device=device)
generated_ids = model.generate(
    context,
    max_new_tokens=cfg.gen_max_new_tokens,
    temperature=cfg.gen_temperature,
    top_k=cfg.gen_top_k,
    eos_id=EOS_ID
)[0].tolist()
print("📝 Sample:\n", decode_ids(generated_ids))

# ---------------------
# Zip checkpoints for download (COLAB)
# ---------------------
print("\n📦 Zipping checkpoints for download...")
os.system(f"zip -r checkpoints.zip {cfg.ckpt_dir}")
print("✅ Run this in a new cell to download:")
print("   from google.colab import files")
print("   files.download('checkpoints.zip')")
# Out:
# ✅ Dataset already exists.
# 🔧 Training new BPE tokenizer...
# ✅ Tokenizer trained and saved.
# 📊 Vocab size: 8000
# 📖 Dataset length (chars): 6,793,953
# 🤖 Model parameters: 6.03 M
# Step 0: train loss 9.0119 (ppl 8199.87), val loss 9.0132 (ppl 8210.97), lr 0.00e+00
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/best.pt
# [Progress: 100/5000 (2.0%)] elapsed 0.2 min
# [Progress: 200/5000 (4.0%)] elapsed 0.4 min
# [Progress: 300/5000 (6.0%)] elapsed 0.6 min
# [Progress: 400/5000 (8.0%)] elapsed 0.8 min
# [Progress: 500/5000 (10.0%)] elapsed 1.0 min
# Step 500: train loss 6.2731 (ppl 530.13), val loss 6.4677 (ppl 644.03), lr 1.50e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/best.pt
# 💾 Checkpoint saved at step 500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/checkpoint_500.pt
# [Progress: 600/5000 (12.0%)] elapsed 1.3 min
# [Progress: 700/5000 (14.0%)] elapsed 1.5 min
# [Progress: 800/5000 (16.0%)] elapsed 1.7 min
# [Progress: 900/5000 (18.0%)] elapsed 1.9 min
# [Progress: 1000/5000 (20.0%)] elapsed 2.1 min
# Step 1000: train loss 5.7894 (ppl 326.80), val loss 6.0968 (ppl 444.44), lr 3.00e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/best.pt
# 💾 Checkpoint saved at step 1000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/checkpoint_1000.pt
# [Progress: 1100/5000 (22.0%)] elapsed 2.3 min
# [Progress: 1200/5000 (24.0%)] elapsed 2.5 min
# [Progress: 1300/5000 (26.0%)] elapsed 2.7 min
# [Progress: 1400/5000 (28.0%)] elapsed 2.9 min
# [Progress: 1500/5000 (30.0%)] elapsed 3.1 min
# Step 1500: train loss 5.5215 (ppl 250.01), val loss 5.9291 (ppl 375.81), lr 2.90e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/best.pt
# 💾 Checkpoint saved at step 1500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/checkpoint_1500.pt
# [Progress: 1600/5000 (32.0%)] elapsed 3.4 min
# [Progress: 1700/5000 (34.0%)] elapsed 3.6 min
# [Progress: 1800/5000 (36.0%)] elapsed 3.8 min
# [Progress: 1900/5000 (38.0%)] elapsed 4.0 min
# [Progress: 2000/5000 (40.0%)] elapsed 4.2 min
# Step 2000: train loss 5.3243 (ppl 205.26), val loss 5.8372 (ppl 342.83), lr 2.60e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/best.pt
# 💾 Checkpoint saved at step 2000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/checkpoint_2000.pt
# [Progress: 2100/5000 (42.0%)] elapsed 4.5 min
# [Progress: 2200/5000 (44.0%)] elapsed 4.7 min
# [Progress: 2300/5000 (46.0%)] elapsed 4.9 min
# [Progress: 2400/5000 (48.0%)] elapsed 5.1 min
# [Progress: 2500/5000 (50.0%)] elapsed 5.3 min
# Step 2500: train loss 5.2244 (ppl 185.75), val loss 5.8097 (ppl 333.51), lr 2.17e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/best.pt
# 💾 Checkpoint saved at step 2500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/checkpoint_2500.pt
# [Progress: 2600/5000 (52.0%)] elapsed 5.5 min
# [Progress: 2700/5000 (54.0%)] elapsed 5.7 min
# [Progress: 2800/5000 (56.0%)] elapsed 5.9 min
# [Progress: 2900/5000 (58.0%)] elapsed 6.1 min
# [Progress: 3000/5000 (60.0%)] elapsed 6.3 min
# Step 3000: train loss 5.1429 (ppl 171.21), val loss 5.7640 (ppl 318.61), lr 1.65e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/best.pt
# 💾 Checkpoint saved at step 3000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/checkpoint_3000.pt
# [Progress: 3100/5000 (62.0%)] elapsed 6.6 min
# [Progress: 3200/5000 (64.0%)] elapsed 6.8 min
# [Progress: 3300/5000 (66.0%)] elapsed 7.0 min
# [Progress: 3400/5000 (68.0%)] elapsed 7.2 min
# [Progress: 3500/5000 (70.0%)] elapsed 7.4 min
# Step 3500: train loss 5.0838 (ppl 161.39), val loss 5.7146 (ppl 303.26), lr 1.13e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/best.pt
# 💾 Checkpoint saved at step 3500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/checkpoint_3500.pt
# [Progress: 3600/5000 (72.0%)] elapsed 7.6 min
# [Progress: 3700/5000 (74.0%)] elapsed 7.8 min
# [Progress: 3800/5000 (76.0%)] elapsed 8.0 min
# [Progress: 3900/5000 (78.0%)] elapsed 8.2 min
# [Progress: 4000/5000 (80.0%)] elapsed 8.4 min
# Step 4000: train loss 5.0524 (ppl 156.39), val loss 5.7177 (ppl 304.20), lr 6.95e-05
# 💾 Checkpoint saved at step 4000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/checkpoint_4000.pt
# [Progress: 4100/5000 (82.0%)] elapsed 8.7 min
# [Progress: 4200/5000 (84.0%)] elapsed 8.9 min
# [Progress: 4300/5000 (86.0%)] elapsed 9.1 min
# [Progress: 4400/5000 (88.0%)] elapsed 9.3 min
# [Progress: 4500/5000 (90.0%)] elapsed 9.5 min
# Step 4500: train loss 5.0188 (ppl 151.22), val loss 5.6917 (ppl 296.39), lr 4.03e-05
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/best.pt
# 💾 Checkpoint saved at step 4500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/checkpoint_4500.pt
# [Progress: 4600/5000 (92.0%)] elapsed 9.7 min
# [Progress: 4700/5000 (94.0%)] elapsed 9.9 min
# [Progress: 4800/5000 (96.0%)] elapsed 10.1 min
# [Progress: 4900/5000 (98.0%)] elapsed 10.3 min
# Step 4999: train loss 5.0197 (ppl 151.37), val loss 5.6871 (ppl 295.04), lr 3.00e-05
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/best.pt
# ✅ Final model saved to /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/gpt_final.pt
# 🌟 Loaded best checkpoint for generation: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_033539/checkpoints/best.pt
# 📝 Sample:
#  " ‘ " हाँ , मुझे न मिला जाता ?’
#
# 📦 Zipping checkpoints for download...
# ✅ Run this in a new cell to download:
#    from google.colab import files
#    files.download('checkpoints.zip')

# %% [markdown]
# **4) Multi-Head Latent Attention**

# %%
import os
import math
import time
import torch
import torch.nn as nn
from torch.nn import functional as F
from dataclasses import dataclass
from typing import Optional
from tokenizers import Tokenizer, models, trainers, pre_tokenizers
from tokenizers.processors import TemplateProcessing

# ---------------------
# Reproducibility
# ---------------------
torch.manual_seed(1337)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# ---------------------
# Config
# ---------------------
@dataclass
class Config:
    # data
    dataset_path: str = "dataset/new_input.txt"
    tokenizer_dir: str = "tokenizer"
    tokenizer_file: str = "tokenizer/bpe_tokenizer.json"
    vocab_size: int = 8000 # changed from 10000
    force_retrain_tokenizer: bool = False  # set True to retrain with ByteLevel BPE
    dataset_token_limit: Optional[int] = 1_500_000  # NEW: faster runs
    # model
    n_embd: int = 320               # CHANGED: 384 -> 320 (faster)
    n_head: int = 6
    n_layer: int = 3                # CHANGED: 4 -> 3 (faster)
    dropout: float = 0.5            # stronger regularization
    emb_dropout: float = 0.1        # new: embedding dropout
    block_size: int = 256
    # attention selection
    attn_type: str = "mlha"        # NEW: "mha" | "mqa" | "gqa" | "mlha"
    num_kv_heads: int = 1         # NEW: for MQA/GQA (MQA=1, GQA>1 and divides n_head)
    latent_kv_heads: int = 4      # NEW: for MLHA (# latent K/V heads)

    # training
    batch_size: int = 32 # changed from 64
    max_iters: int = 5000 # changed from 25000 for faster runs
    eval_interval: int = 500      # CHANGED: 1000 -> 500
    eval_iters: int = 50 # changed from 200
    learning_rate: float = 3e-4
    min_lr: float = 3e-5
    warmup_iters: int = 1000      # CHANGED: 2000 -> 1000
    weight_decay: float = 0.1
    betas: tuple = (0.9, 0.95)
    grad_clip: float = 1.0
    grad_accum_steps: int = 2 # changed from 1
    use_amp: bool = True
    patience_evals: int = 6        # new: early stopping patience
    save_every: int = 500
    ckpt_dir: str = "checkpoints"
    resume_path: Optional[str] = None
    use_best_for_generation: bool = True   # NEW
    # loss
    label_smoothing: float = 0.1   # new: improves generalization
    # generation
    gen_max_new_tokens: int = 700
    gen_temperature: float = 1.0
    gen_top_k: int = 50

cfg = Config()
# === [NEW] Set up Drive output directories ===
import datetime
run_id = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
drive_root = f"/content/drive/MyDrive/gpt_from_scratch_runs/run_{run_id}"

cfg.ckpt_dir = os.path.join(drive_root, "checkpoints")
cfg.tokenizer_dir = os.path.join(drive_root, "tokenizer")
cfg.tokenizer_file = os.path.join(cfg.tokenizer_dir, "bpe_tokenizer.json")
os.makedirs(cfg.ckpt_dir, exist_ok=True)
os.makedirs(cfg.tokenizer_dir, exist_ok=True)

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# ---------------------
# Clone dataset repo (COLAB)
# ---------------------
if not os.path.exists(cfg.dataset_path):
    print("📥 Cloning dataset repo...")
    os.system("git clone https://github.com/DevashishXO/GPT-From-Scratch.git")
    os.chdir("GPT-From-Scratch")
else:
    print("✅ Dataset already exists.")

# ---------------------
# Tokenizer setup
# ---------------------
os.makedirs(cfg.tokenizer_dir, exist_ok=True)

def train_or_load_tokenizer():
    tok_path = cfg.tokenizer_file
    if cfg.force_retrain_tokenizer and os.path.exists(tok_path):
        print("♻️ Forcing tokenizer retrain, removing old file...")
        try:
            os.remove(tok_path)
        except FileNotFoundError:
            pass

    if not os.path.exists(tok_path):
        print("🔧 Training new BPE tokenizer...")
        tokenizer = Tokenizer(models.BPE(unk_token="[UNK]"))
        # ByteLevel is more robust for multilingual/raw punctuation; switch if retraining
        tokenizer.pre_tokenizer = pre_tokenizers.ByteLevel() if cfg.force_retrain_tokenizer else pre_tokenizers.Whitespace()
        trainer = trainers.BpeTrainer(
            vocab_size=cfg.vocab_size,
            special_tokens=["[PAD]", "[UNK]", "[BOS]", "[EOS]"]
        )
        tokenizer.train([cfg.dataset_path], trainer)
        if isinstance(tokenizer.model, models.BPE):
            tokenizer.model.unk_token = "[UNK]"
        bos_id = tokenizer.token_to_id("[BOS]")
        eos_id = tokenizer.token_to_id("[EOS]")
        tokenizer.post_processor = TemplateProcessing(
            single="[BOS] $A [EOS]",
            pair="[BOS] $A [EOS] [BOS] $B [EOS]",
            special_tokens=[("[BOS]", bos_id), ("[EOS]", eos_id)]
        )
        tokenizer.save(tok_path)
        print("✅ Tokenizer trained and saved.")
    else:
        print("✅ Existing tokenizer found. Loading...")
    tokenizer = Tokenizer.from_file(tok_path)
    if isinstance(tokenizer.model, models.BPE) and tokenizer.model.unk_token is None:
        tokenizer.model.unk_token = "[UNK]"
    bos_id = tokenizer.token_to_id("[BOS]")
    eos_id = tokenizer.token_to_id("[EOS]")
    if tokenizer.post_processor is None:
        tokenizer.post_processor = TemplateProcessing(
            single="[BOS] $A [EOS]",
            pair="[BOS] $A [EOS] [BOS] $B [EOS]",
            special_tokens=[("[BOS]", bos_id), ("[EOS]", eos_id)]
        )
    return tokenizer

tokenizer = train_or_load_tokenizer()
vocab_size = tokenizer.get_vocab_size()
print(f"📊 Vocab size: {vocab_size}")

BOS_ID = tokenizer.token_to_id("[BOS]")
EOS_ID = tokenizer.token_to_id("[EOS]")

def encode_text_stream_with_boundaries(txt: str) -> list[int]:
    ids: list[int] = []
    for line in txt.splitlines():
        line = line.strip()
        if not line:
            continue
        ids.extend(tokenizer.encode(line).ids)  # post-processor injects BOS/EOS
    return ids

def decode_ids(ids: list[int]) -> str:
    return tokenizer.decode(ids, skip_special_tokens=True)

# ---------------------
# Load dataset
# ---------------------
with open(cfg.dataset_path, "r", encoding="utf-8") as f:
    raw_text = f.read()
print(f"📖 Dataset length (chars): {len(raw_text):,}")

all_ids = encode_text_stream_with_boundaries(raw_text)
data = torch.tensor(all_ids, dtype=torch.long)
if len(data) < cfg.block_size + 1:
    raise ValueError(f"Encoded dataset too small ({len(data)}) for block_size={cfg.block_size}")

n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

def get_batch(split: str):
    src = train_data if split == 'train' else val_data
    ix = torch.randint(0, len(src) - cfg.block_size, (cfg.batch_size,))
    x = torch.stack([src[i:i+cfg.block_size] for i in ix])
    y = torch.stack([src[i+1:i+cfg.block_size+1] for i in ix])
    return x.to(device), y.to(device)

# ---------------------
# LR schedule
# ---------------------
def cosine_lr(step: int, base_lr: float, min_lr: float, warmup: int, total: int):
    if step < warmup:
        return base_lr * step / max(1, warmup)
    progress = (step - warmup) / max(1, total - warmup)
    return min_lr + 0.5 * (base_lr - min_lr) * (1 + math.cos(math.pi * progress))

# ---------------------
# Model
# ---------------------
class Head(nn.Module):
    def __init__(self, head_size: int):
        super().__init__()
        self.key = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.query = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.value = nn.Linear(cfg.n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(cfg.block_size, cfg.block_size)))
        self.dropout = nn.Dropout(cfg.dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x); q = self.query(x)
        wei = q @ k.transpose(-2, -1) * (k.shape[-1] ** -0.5)
        # AMP-stable mask
        wei = wei.masked_fill(self.tril[:T, :T] == 0, torch.finfo(wei.dtype).min)
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        out = wei @ v
        return out

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads: int, head_size: int):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(head_size * num_heads, cfg.n_embd)
        self.dropout = nn.Dropout(cfg.dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out
    pass

# NEW: MQA/GQA/MLHA implementations (project Q/K/V once and reshape)
class MultiQueryAttention(nn.Module):
    def __init__(self, n_embd: int, n_head: int, kv_heads: int):
        super().__init__()
        assert n_head % kv_heads == 0, "n_head must be divisible by kv_heads"
        self.n_head = n_head
        self.kv_heads = kv_heads
        self.head_size = n_embd // n_head
        self.q_proj = nn.Linear(n_embd, n_head * self.head_size, bias=False)
        self.k_proj = nn.Linear(n_embd, kv_heads * self.head_size, bias=False)
        self.v_proj = nn.Linear(n_embd, kv_heads * self.head_size, bias=False)
        self.proj = nn.Linear(n_head * self.head_size, n_embd)
        self.dropout = nn.Dropout(cfg.dropout)
        self.register_buffer('tril', torch.tril(torch.ones(cfg.block_size, cfg.block_size)))

    def forward(self, x):
        B, T, C = x.shape
        q = self.q_proj(x).view(B, T, self.n_head, self.head_size).transpose(1, 2)  # (B,H,T,dh)
        k = self.k_proj(x).view(B, T, self.kv_heads, self.head_size).transpose(1, 2)  # (B,KV,T,dh)
        v = self.v_proj(x).view(B, T, self.kv_heads, self.head_size).transpose(1, 2)  # (B,KV,T,dh)

        if self.kv_heads != self.n_head:
            repeat = self.n_head // self.kv_heads
            k = k.repeat_interleave(repeat, dim=1)  # (B,H,T,dh)
            v = v.repeat_interleave(repeat, dim=1)  # (B,H,T,dh)

        att = (q @ k.transpose(-2, -1)) * (self.head_size ** -0.5)  # (B,H,T,T)
        att = att.masked_fill(self.tril[:T, :T] == 0, torch.finfo(att.dtype).min)
        att = F.softmax(att, dim=-1)
        att = self.dropout(att)
        out = att @ v  # (B,H,T,dh)
        out = out.transpose(1, 2).contiguous().view(B, T, self.n_head * self.head_size)
        return self.dropout(self.proj(out))

class MultiHeadLatentAttention(nn.Module):
    def __init__(self, n_embd: int, n_head: int, latent_heads: int):
        super().__init__()
        assert n_head >= 1 and latent_heads >= 1
        self.n_head = n_head
        self.latent_heads = latent_heads
        self.head_size = n_embd // n_head
        self.q_proj = nn.Linear(n_embd, n_head * self.head_size, bias=False)
        self.k_lat_proj = nn.Linear(n_embd, latent_heads * self.head_size, bias=False)
        self.v_lat_proj = nn.Linear(n_embd, latent_heads * self.head_size, bias=False)
        # mixing matrix to map latent heads -> per-head K/V
        self.mix = nn.Parameter(torch.empty(n_head, latent_heads))
        nn.init.normal_(self.mix, mean=0.0, std=1.0 / max(1, latent_heads))
        self.proj = nn.Linear(n_head * self.head_size, n_embd)
        self.dropout = nn.Dropout(cfg.dropout)
        self.register_buffer('tril', torch.tril(torch.ones(cfg.block_size, cfg.block_size)))

    def forward(self, x):
        B, T, C = x.shape
        q = self.q_proj(x).view(B, T, self.n_head, self.head_size).transpose(1, 2)  # (B,H,T,dh)
        k_lat = self.k_lat_proj(x).view(B, T, self.latent_heads, self.head_size).transpose(1, 2)  # (B,L,T,dh)
        v_lat = self.v_lat_proj(x).view(B, T, self.latent_heads, self.head_size).transpose(1, 2)  # (B,L,T,dh)

        w = torch.softmax(self.mix, dim=-1)  # (H,L)
        # mix latent K/V into per-head K/V
        k = torch.einsum("bltd,hl->bhtd", k_lat, w)  # (B,H,T,dh)
        v = torch.einsum("bltd,hl->bhtd", v_lat, w)  # (B,H,T,dh)

        att = (q @ k.transpose(-2, -1)) * (self.head_size ** -0.5)  # (B,H,T,T)
        att = att.masked_fill(self.tril[:T, :T] == 0, torch.finfo(att.dtype).min)
        att = F.softmax(att, dim=-1)
        att = self.dropout(att)
        out = att @ v  # (B,H,T,dh)
        out = out.transpose(1, 2).contiguous().view(B, T, self.n_head * self.head_size)
        return self.dropout(self.proj(out))

class FeedForward(nn.Module):
    def __init__(self, n_embd: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.GELU(),  # GELU generally improves GPTs
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(cfg.dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    def __init__(self, n_embd: int, n_head: int):
        super().__init__()
        head_size = n_embd // n_head
# SELECT ATTENTION HERE
        if cfg.attn_type == "mha":
            self.sa = MultiHeadAttention(n_head, head_size)
        elif cfg.attn_type == "mqa":
            self.sa = MultiQueryAttention(n_embd=n_embd, n_head=n_head, kv_heads=1)
        elif cfg.attn_type == "gqa":
            self.sa = MultiQueryAttention(n_embd=n_embd, n_head=n_head, kv_heads=cfg.num_kv_heads)
        elif cfg.attn_type == "mlha":
            self.sa = MultiHeadLatentAttention(n_embd=n_embd, n_head=n_head, latent_heads=cfg.latent_kv_heads)
        else:
            raise ValueError(f"Unknown attn_type: {cfg.attn_type}")
        self.ff = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ff(self.ln2(x))
        return x

class GPTLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, cfg.n_embd)
        self.position_embedding_table = nn.Embedding(cfg.block_size, cfg.n_embd)
        self.drop_emb = nn.Dropout(cfg.emb_dropout)  # new: embedding dropout
        self.blocks = nn.Sequential(*[Block(cfg.n_embd, cfg.n_head) for _ in range(cfg.n_layer)])
        self.ln_f = nn.LayerNorm(cfg.n_embd)
        self.lm_head = nn.Linear(cfg.n_embd, vocab_size, bias=False)
        self.apply(self._init_weights)
        self.tie_weights()

    def tie_weights(self):
        self.lm_head.weight = self.token_embedding_table.weight

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=idx.device))
        x = self.drop_emb(tok_emb + pos_emb)  # apply embedding dropout
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)
        loss = None
        if targets is not None:
            loss = F.cross_entropy(
                logits.view(B*T, -1),
                targets.view(B*T),
                label_smoothing=cfg.label_smoothing,  # new: label smoothing
            )
        return logits, loss

    @torch.no_grad()
    def _sample_next(self, logits_last, temperature=1.0, top_k=50):
        if temperature != 1.0:
            logits_last = logits_last / temperature
        probs = F.softmax(logits_last, dim=-1)
        if top_k is not None and top_k > 0:
            v, ix = torch.topk(probs, top_k)
            mask = torch.ones_like(probs, dtype=torch.bool)
            mask.scatter_(1, ix, False)
            probs = probs.masked_fill(mask, 0)
            probs = probs / probs.sum(dim=-1, keepdim=True)
        next_token = torch.multinomial(probs, num_samples=1)
        return next_token

    @torch.no_grad()
    def generate(self, idx, max_new_tokens, temperature=1.0, top_k=50, eos_id: int | None = None):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -cfg.block_size:]
            logits, _ = self(idx_cond)
            next_token = self._sample_next(logits[:, -1, :], temperature, top_k)
            idx = torch.cat((idx, next_token), dim=1)
            if eos_id is not None and (next_token == eos_id).all():
                break
        return idx

# ---------------------
# Init model/opt/amp
# ---------------------
model = GPTLanguageModel().to(device)

# AdamW param groups: no weight decay on LayerNorm or bias
decay = []
no_decay = []
for name, param in model.named_parameters():
    if name.endswith('bias') or 'ln' in name or 'norm' in name:
        no_decay.append(param)
    else:
        decay.append(param)

optim_groups = [
    {"params": decay, "weight_decay": cfg.weight_decay},
    {"params": no_decay, "weight_decay": 0.0},
]

optimizer = torch.optim.AdamW(
    optim_groups,
    lr=cfg.learning_rate,
    betas=cfg.betas
)

# Use new torch.amp API (fixes deprecation warnings)
scaler = torch.amp.GradScaler('cuda', enabled=(cfg.use_amp and device == 'cuda'))

param_millions = sum(p.numel() for p in model.parameters())/1e6
print(f"🤖 Model parameters: {param_millions:.2f} M")

os.makedirs(cfg.ckpt_dir, exist_ok=True)

start_iter = 0
best_val_loss = float('inf')
no_improve_evals = 0
if cfg.resume_path is not None and os.path.exists(cfg.resume_path):
    ckpt = torch.load(cfg.resume_path, map_location=device)
    model.load_state_dict(ckpt['model'])
    optimizer.load_state_dict(ckpt['opt'])
    start_iter = ckpt.get('iter', 0) + 1
    best_val_loss = ckpt.get('val_loss', float('inf'))
    print(f"🔄 Resumed from {cfg.resume_path} at iter {start_iter}, best_val_loss={best_val_loss:.4f}")

@torch.no_grad()
def estimate_metrics():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(cfg.eval_iters, device=device)
        for k in range(cfg.eval_iters):
            X, Y = get_batch(split)
            with torch.amp.autocast('cuda', enabled=(cfg.use_amp and device == 'cuda')):
                _, loss = model(X, Y)
            losses[k] = loss
        mean_loss = losses.mean().item()
        out[split] = {'loss': mean_loss, 'ppl': math.exp(mean_loss)}
    model.train()
    return out

# ---------------------
# Training
# ---------------------
t0 = time.time()
for iter in range(start_iter, cfg.max_iters):
    lr = cosine_lr(iter, cfg.learning_rate, cfg.min_lr, cfg.warmup_iters, cfg.max_iters)
    for g in optimizer.param_groups:
        g['lr'] = lr

    if iter % 100 == 0 and iter > 0:
        elapsed = time.time() - t0
        print(f"[Progress: {iter}/{cfg.max_iters} ({100*iter/cfg.max_iters:.1f}%)] elapsed {elapsed/60:.1f} min")

    if iter % cfg.eval_interval == 0 or iter == cfg.max_iters - 1:
        metrics = estimate_metrics()
        print(f"Step {iter}: train loss {metrics['train']['loss']:.4f} (ppl {metrics['train']['ppl']:.2f}), "
              f"val loss {metrics['val']['loss']:.4f} (ppl {metrics['val']['ppl']:.2f}), lr {lr:.2e}")
        if metrics['val']['loss'] + 1e-6 < best_val_loss:
            best_val_loss = metrics['val']['loss']
            no_improve_evals = 0
            best_path = os.path.join(cfg.ckpt_dir, "best.pt")
            torch.save({'iter': iter, 'model': model.state_dict(), 'opt': optimizer.state_dict(),
                        'val_loss': best_val_loss, 'cfg': cfg.__dict__}, best_path)
            print(f" -> 💾 Best checkpoint updated: {best_path}")
        else:
            no_improve_evals += 1
            if no_improve_evals >= cfg.patience_evals:
                print(f"⏹️ Early stopping after {no_improve_evals} evals without val improvement.")
                break

    optimizer.zero_grad(set_to_none=True)
    for micro in range(cfg.grad_accum_steps):
        xb, yb = get_batch('train')
        with torch.amp.autocast('cuda', enabled=(cfg.use_amp and device == 'cuda')):
            _, loss = model(xb, yb)
            loss = loss / cfg.grad_accum_steps
        scaler.scale(loss).backward()

    if cfg.grad_clip and cfg.grad_clip > 0:
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)

    scaler.step(optimizer)
    scaler.update()

    if iter > 0 and iter % cfg.save_every == 0:
        ckpt_path = os.path.join(cfg.ckpt_dir, f"checkpoint_{iter}.pt")
        torch.save({'iter': iter, 'model': model.state_dict(), 'opt': optimizer.state_dict(),
                    'val_loss': best_val_loss, 'cfg': cfg.__dict__}, ckpt_path)
        print(f"💾 Checkpoint saved at step {iter}: {ckpt_path}")

# ---------------------
# Save final, generate sample
# ---------------------
final_model_path = os.path.join(cfg.ckpt_dir, "gpt_final.pt")
torch.save(model.state_dict(), final_model_path)
print(f"✅ Final model saved to {final_model_path}")

# NEW: optionally reload best.pt for generation
best_path = os.path.join(cfg.ckpt_dir, "best.pt")
if cfg.use_best_for_generation and os.path.exists(best_path):
    try:
        ckpt = torch.load(best_path, map_location=device)
        model.load_state_dict(ckpt["model"])
        print(f"🌟 Loaded best checkpoint for generation: {best_path}")
    except Exception as e:
        print(f"⚠️ Could not load best.pt for generation: {e}")

context = torch.tensor([[BOS_ID]], dtype=torch.long, device=device)
generated_ids = model.generate(
    context,
    max_new_tokens=cfg.gen_max_new_tokens,
    temperature=cfg.gen_temperature,
    top_k=cfg.gen_top_k,
    eos_id=EOS_ID
)[0].tolist()
print("📝 Sample:\n", decode_ids(generated_ids))

# ---------------------
# Zip checkpoints for download (COLAB)
# ---------------------
print("\n📦 Zipping checkpoints for download...")
os.system(f"zip -r checkpoints.zip {cfg.ckpt_dir}")
print("✅ Run this in a new cell to download:")
print("   from google.colab import files")
print("   files.download('checkpoints.zip')")
# Out:
# ✅ Dataset already exists.
# 🔧 Training new BPE tokenizer...
# ✅ Tokenizer trained and saved.
# 📊 Vocab size: 8000
# 📖 Dataset length (chars): 6,793,953
# 🤖 Model parameters: 6.13 M
# Step 0: train loss 9.0657 (ppl 8652.99), val loss 9.0635 (ppl 8634.08), lr 0.00e+00
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/best.pt
# [Progress: 100/5000 (2.0%)] elapsed 0.3 min
# [Progress: 200/5000 (4.0%)] elapsed 0.5 min
# [Progress: 300/5000 (6.0%)] elapsed 0.7 min
# [Progress: 400/5000 (8.0%)] elapsed 0.9 min
# [Progress: 500/5000 (10.0%)] elapsed 1.1 min
# Step 500: train loss 6.2148 (ppl 500.11), val loss 6.4350 (ppl 623.27), lr 1.50e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/best.pt
# 💾 Checkpoint saved at step 500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/checkpoint_500.pt
# [Progress: 600/5000 (12.0%)] elapsed 1.4 min
# [Progress: 700/5000 (14.0%)] elapsed 1.6 min
# [Progress: 800/5000 (16.0%)] elapsed 1.8 min
# [Progress: 900/5000 (18.0%)] elapsed 2.0 min
# [Progress: 1000/5000 (20.0%)] elapsed 2.2 min
# Step 1000: train loss 5.7777 (ppl 323.01), val loss 6.0764 (ppl 435.45), lr 3.00e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/best.pt
# 💾 Checkpoint saved at step 1000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/checkpoint_1000.pt
# [Progress: 1100/5000 (22.0%)] elapsed 2.5 min
# [Progress: 1200/5000 (24.0%)] elapsed 2.7 min
# [Progress: 1300/5000 (26.0%)] elapsed 2.9 min
# [Progress: 1400/5000 (28.0%)] elapsed 3.1 min
# [Progress: 1500/5000 (30.0%)] elapsed 3.3 min
# Step 1500: train loss 5.5093 (ppl 246.97), val loss 5.9451 (ppl 381.88), lr 2.90e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/best.pt
# 💾 Checkpoint saved at step 1500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/checkpoint_1500.pt
# [Progress: 1600/5000 (32.0%)] elapsed 3.6 min
# [Progress: 1700/5000 (34.0%)] elapsed 3.8 min
# [Progress: 1800/5000 (36.0%)] elapsed 4.0 min
# [Progress: 1900/5000 (38.0%)] elapsed 4.2 min
# [Progress: 2000/5000 (40.0%)] elapsed 4.5 min
# Step 2000: train loss 5.3399 (ppl 208.49), val loss 5.8563 (ppl 349.42), lr 2.60e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/best.pt
# 💾 Checkpoint saved at step 2000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/checkpoint_2000.pt
# [Progress: 2100/5000 (42.0%)] elapsed 4.7 min
# [Progress: 2200/5000 (44.0%)] elapsed 4.9 min
# [Progress: 2300/5000 (46.0%)] elapsed 5.1 min
# [Progress: 2400/5000 (48.0%)] elapsed 5.4 min
# [Progress: 2500/5000 (50.0%)] elapsed 5.6 min
# Step 2500: train loss 5.2318 (ppl 187.14), val loss 5.8037 (ppl 331.52), lr 2.17e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/best.pt
# 💾 Checkpoint saved at step 2500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/checkpoint_2500.pt
# [Progress: 2600/5000 (52.0%)] elapsed 5.8 min
# [Progress: 2700/5000 (54.0%)] elapsed 6.0 min
# [Progress: 2800/5000 (56.0%)] elapsed 6.3 min
# [Progress: 2900/5000 (58.0%)] elapsed 6.5 min
# [Progress: 3000/5000 (60.0%)] elapsed 6.7 min
# Step 3000: train loss 5.1456 (ppl 171.67), val loss 5.7496 (ppl 314.05), lr 1.65e-04
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/best.pt
# 💾 Checkpoint saved at step 3000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/checkpoint_3000.pt
# [Progress: 3100/5000 (62.0%)] elapsed 6.9 min
# [Progress: 3200/5000 (64.0%)] elapsed 7.1 min
# [Progress: 3300/5000 (66.0%)] elapsed 7.4 min
# [Progress: 3400/5000 (68.0%)] elapsed 7.6 min
# [Progress: 3500/5000 (70.0%)] elapsed 7.8 min
# Step 3500: train loss 5.0960 (ppl 163.36), val loss 5.7523 (ppl 314.92), lr 1.13e-04
# 💾 Checkpoint saved at step 3500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/checkpoint_3500.pt
# [Progress: 3600/5000 (72.0%)] elapsed 8.0 min
# [Progress: 3700/5000 (74.0%)] elapsed 8.3 min
# [Progress: 3800/5000 (76.0%)] elapsed 8.5 min
# [Progress: 3900/5000 (78.0%)] elapsed 8.7 min
# [Progress: 4000/5000 (80.0%)] elapsed 8.9 min
# Step 4000: train loss 5.0484 (ppl 155.78), val loss 5.6952 (ppl 297.45), lr 6.95e-05
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/best.pt
# 💾 Checkpoint saved at step 4000: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/checkpoint_4000.pt
# [Progress: 4100/5000 (82.0%)] elapsed 9.2 min
# [Progress: 4200/5000 (84.0%)] elapsed 9.4 min
# [Progress: 4300/5000 (86.0%)] elapsed 9.6 min
# [Progress: 4400/5000 (88.0%)] elapsed 9.8 min
# [Progress: 4500/5000 (90.0%)] elapsed 10.0 min
# Step 4500: train loss 5.0312 (ppl 153.11), val loss 5.7047 (ppl 300.27), lr 4.03e-05
# 💾 Checkpoint saved at step 4500: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/checkpoint_4500.pt
# [Progress: 4600/5000 (92.0%)] elapsed 10.3 min
# [Progress: 4700/5000 (94.0%)] elapsed 10.5 min
# [Progress: 4800/5000 (96.0%)] elapsed 10.7 min
# [Progress: 4900/5000 (98.0%)] elapsed 10.9 min
# Step 4999: train loss 5.0139 (ppl 150.49), val loss 5.6943 (ppl 297.16), lr 3.00e-05
#  -> 💾 Best checkpoint updated: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/best.pt
# ✅ Final model saved to /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/gpt_final.pt
# 🌟 Loaded best checkpoint for generation: /content/drive/MyDrive/gpt_from_scratch_runs/run_20251119_035204/checkpoints/best.pt
# 📝 Sample:
#  सलीम का मुंह से हटा दिया । उसने एक क्षण के लिए से भरे हुए कहा - नहीं अम्मां , तुम मुझे किसी तरह नहीं होते , मैं भी कहती हूं , तुम नहीं तो मैं भी तुम्हारे लिए जा रही हूं । तुम क्या हो , मुझे तुम मेरी जान क्यों खड़े - जाते हो जाओगे ?
#
# 📦 Zipping checkpoints for download...
# ✅ Run this in a new cell to download:
#    from google.colab import files
#    files.download('checkpoints.zip')
